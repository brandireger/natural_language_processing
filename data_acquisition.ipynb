# %% [markdown]
# # Exercises
#
# ### 1. Codeup Blog Articles
#
# Scrape the article text from the following pages:
#
# - [link](https://codeup.com/codeups-data-science-career-accelerator-is-here/>)
# - [link](https://codeup.com/data-science-myths/)
# - [link](https://codeup.com/data-science-vs-data-analytics-whats-the-difference/)
# - [link](https://codeup.com/10-tips-to-crush-it-at-the-sa-tech-job-fair/)
# - [link](https://codeup.com/competitor-bootcamps-are-closing-is-the-model-in-danger/)
#
# Encapsulate your work in a function named get_blog_articles that will return a list of dictionaries, with each dictionary representing one article. The shape of each dictionary should look like this:

# %%
{
    'title': 'the title of the article',
    'content': 'the full text content of the article'
}
# Out:
# {'title': 'the title of the article',
#  'content': 'the full text content of the article'}

# %% [markdown]
# Plus any additional properties you think might be helpful.

# %%
#1. Import the get() function from the requests module, BeautifulSoup from bs4, and pandas.

import numpy as np
import pandas as pd
import re

from requests import get
from bs4 import BeautifulSoup
import os

# %%
#2. Assign the address of the web page to a variable named url.
url = 'https://codeup.com/codeups-data-science-career-accelerator-is-here/'

# %%
#3. Request the server the content of the web page by using get(), and store the server’s response in the variable response.
headers = {'User-Agent': 'Codeup Data Science'}
response = get(url, headers=headers)

# %%
#4. Print the response text to ensure you have an html page.
print(response.text[:400])
# Out:
# <!DOCTYPE html><html lang="en-US"><head ><meta charset="UTF-8" /><meta name="viewport" content="width=device-width, initial-scale=1" /> <script>function fvmuag(){if(navigator.userAgent.match(/x11.*fox\/54|oid\s4.*xus.*ome\/62|oobot|ighth|tmetr|eadles|ingdo/i))return!1;if(navigator.userAgent.match(/x11.*ome\/75\.0\.3770\.100/i)){var e=screen.width,t=screen.height;if("number"==typeof e&&"number"==ty

# %%
#5. Take a look at the actual web page contents and inspect the source to understand the structure a bit.

# %%
#6. Use BeautifulSoup to parse the HTML into a variable ('soup').
soup = BeautifulSoup(response.content, 'html.parser')

# %%
#7. Identify the key tags you need to extract the data you are looking for.
soup.title.text
# Out:
# 'Codeup’s Data Science Career Accelerator is Here! - Codeup'

# %%
soup.article.text
# Out:
# 'Codeup’s Data Science Career Accelerator is Here!Posted on September 30, 2018In San AntonioThe rumors are true! The time has arrived. Codeup has officially opened applications to our new Data Science career accelerator, with only 25 seats available! This immersive program is one of a kind in San Antonio, and will help you land a job in\xa0Glassdoor’s #1 Best Job in America.Data Science is a method of providing actionable intelligence from data.\xa0The data revolution has hit San Antonio,\xa0resulting in an explosion in Data Scientist positions\xa0across companies like USAA, Accenture, Booz Allen Hamilton, and HEB. We’ve even seen\xa0UTSA invest $70 M for a Cybersecurity Center and School of Data Science.\xa0We built a program to specifically meet the growing demands of this industry.Our program will be 18 weeks long, full-time, hands-on, and project-based. Our curriculum development and instruction is led by Senior Data Scientist, Maggie Giust, who has worked at HEB, Capital Group, and Rackspace, along with input from dozens of practitioners and hiring partners. Students will work with real data sets, realistic problems, and the entire data science pipeline from collection to deployment. They will receive professional development training in resume writing, interviewing, and continuing education to prepare for a smooth transition to the workforce.We focus on applied data science for immediate impact and ROI in a business, which is how we can back it all up with a 6 month tuition refund guarantee – just like our existing Web Dev program. We’re focusing on Data Science with Python, SQL, and ML, covered in\xa014 modules: 1) Fundamentals; 2) Applied statistics; 3) SQL; 4) Python; 5) Supervised machine learning – regression; 6) Supervised machine learning – classification; 7) Unsupervised machine learning – clustering; 8) Time series analysis; 9) Anomaly detection; 10) Natural language processing; 11) Distributed machine learning; 12) Advanced topics (deep learning, NoSQL, cloud deployment, etc.); 13) Storytelling with data; and 14) Domain expertise development.Applications are now open\xa0for Codeup’s first Data Science cohort, which will start class on February 4, 2019. Hurry – there are only 25 seats available! To further our mission of cultivating inclusive growth, scholarships will be available to women, minorities, LGBTQIA+ individuals, veterans, first responders, and people relocating to San Antonio.If you want to learn about joining our program or hiring our graduates, email datascience@codeup.com!FacebookTwitterLinkedIn'

# %%
soup.find('div', itemprop='text').text
# Out:
# 'The rumors are true! The time has arrived. Codeup has officially opened applications to our new Data Science career accelerator, with only 25 seats available! This immersive program is one of a kind in San Antonio, and will help you land a job in\xa0Glassdoor’s #1 Best Job in America.Data Science is a method of providing actionable intelligence from data.\xa0The data revolution has hit San Antonio,\xa0resulting in an explosion in Data Scientist positions\xa0across companies like USAA, Accenture, Booz Allen Hamilton, and HEB. We’ve even seen\xa0UTSA invest $70 M for a Cybersecurity Center and School of Data Science.\xa0We built a program to specifically meet the growing demands of this industry.Our program will be 18 weeks long, full-time, hands-on, and project-based. Our curriculum development and instruction is led by Senior Data Scientist, Maggie Giust, who has worked at HEB, Capital Group, and Rackspace, along with input from dozens of practitioners and hiring partners. Students will work with real data sets, realistic problems, and the entire data science pipeline from collection to deployment. They will receive professional development training in resume writing, interviewing, and continuing education to prepare for a smooth transition to the workforce.We focus on applied data science for immediate impact and ROI in a business, which is how we can back it all up with a 6 month tuition refund guarantee – just like our existing Web Dev program. We’re focusing on Data Science with Python, SQL, and ML, covered in\xa014 modules: 1) Fundamentals; 2) Applied statistics; 3) SQL; 4) Python; 5) Supervised machine learning – regression; 6) Supervised machine learning – classification; 7) Unsupervised machine learning – clustering; 8) Time series analysis; 9) Anomaly detection; 10) Natural language processing; 11) Distributed machine learning; 12) Advanced topics (deep learning, NoSQL, cloud deployment, etc.); 13) Storytelling with data; and 14) Domain expertise development.Applications are now open\xa0for Codeup’s first Data Science cohort, which will start class on February 4, 2019. Hurry – there are only 25 seats available! To further our mission of cultivating inclusive growth, scholarships will be available to women, minorities, LGBTQIA+ individuals, veterans, first responders, and people relocating to San Antonio.If you want to learn about joining our program or hiring our graduates, email datascience@codeup.com!'

# %%
#8. Create a dataframe of the data desired.
df = pd.DataFrame({
    'title': [soup.title.text],
    'content': [soup.find('div', itemprop='text').text]
})

# %%
#9. Run some summary stats and inspect the data to ensure you have what you wanted.
df
# Out:
#                                                title  \
# 0  Codeup’s Data Science Career Accelerator is He...
#
#                                              content
# 0  The rumors are true! The time has arrived. Cod...

# %%
#10. Edit the data structure as needed, especially so that one column has all the text you want included in this analysis.
#11. Create a corpus of the column with the text you want to analyze.
#12. Store that corpus for use in a future notebook.

# %%
url = 'https://codeup.com/codeups-data-science-career-accelerator-is-here/'
regexp = r'https://codeup.com/(?P<article_name>.+?)/'
article_name = re.match(regexp, url).groups()[0]
article_name
# Out:
# 'codeups-data-science-career-accelerator-is-here'

# %%
def get_codeup_articles(url):
    headers = {'User-Agent': 'Codeup Data Science'}
    response = get(url, headers=headers)
    soup = BeautifulSoup(response.text)
    title = soup.title.text
    article = soup.find('div', itemprop='text').text

    # save it for next time
    regexp = r'https://codeup.com/(?P<article_name>.+?)/'
    article_name = re.match(regexp, url).groups()[0]
    with open(f'{article_name}.txt', 'w') as f:
        f.write(article)

    return title, article

# %%
urls = ['https://codeup.com/codeups-data-science-career-accelerator-is-here/', 
        'https://codeup.com/data-science-myths/',
        'https://codeup.com/data-science-vs-data-analytics-whats-the-difference/',
        'https://codeup.com/10-tips-to-crush-it-at-the-sa-tech-job-fair/',
        'https://codeup.com/competitor-bootcamps-are-closing-is-the-model-in-danger/']

article_df = pd.DataFrame(columns=['title', 'content'])

for url in urls:
    title, article = get_codeup_articles(url)
    article_df = article_df.append({'title': title, 'content': article}, ignore_index=True)
    
article_df
# Out:
#                                                title  \
# 0  Codeup’s Data Science Career Accelerator is He...
# 1                        Data Science Myths - Codeup
# 2  Data Science VS Data Analytics: What’s The Dif...
# 3  10 Tips to Crush It at the SA Tech Job Fair - ...
# 4  Competitor Bootcamps Are Closing. Is the Model...
#
#                                              content
# 0  The rumors are true! The time has arrived. Cod...
# 1  By Dimitri Antoniou and Maggie GiustData Scien...
# 2  By Dimitri AntoniouA week ago, Codeup launched...
# 3  10 Tips to Crush It at the SA Tech Job FairSA ...
# 4  Competitor Bootcamps Are Closing. Is the Model...

# %%
def make_codeup_articles_df(url_list):
    article_df = pd.DataFrame(columns=['title', 'content'])
    for url in url_list:
        title, article = get_codeup_articles(url)
        article_df = article_df.append({'title': title, 'content': article}, ignore_index=True)
    return article_df

codeup_df = make_codeup_articles_df(urls)
codeup_df
# Out:
#                                                title  \
# 0  Codeup’s Data Science Career Accelerator is He...
# 1                        Data Science Myths - Codeup
# 2  Data Science VS Data Analytics: What’s The Dif...
# 3  10 Tips to Crush It at the SA Tech Job Fair - ...
# 4  Competitor Bootcamps Are Closing. Is the Model...
#
#                                              content
# 0  The rumors are true! The time has arrived. Cod...
# 1  By Dimitri Antoniou and Maggie GiustData Scien...
# 2  By Dimitri AntoniouA week ago, Codeup launched...
# 3  10 Tips to Crush It at the SA Tech Job FairSA ...
# 4  Competitor Bootcamps Are Closing. Is the Model...

# %% [markdown]
# ### 2. News Articles
#
# We will now be scraping text data from inshorts, a website that provides a brief overview of many different topics.
#
# Write a function that scrapes the news articles for the following topics:
#
# - Business
# - Sports
# - Technology
# - Entertainment
#
# The end product of this should be a function named get_news_articles that returns a list of dictionaries, where each dictionary has this shape:

# %%
{
    'title': 'The article title',
    'content': 'The article content',
    'category': 'business' # for example
}
# Out:
# {'title': 'The article title',
#  'content': 'The article content',
#  'category': 'business'}

# %% [markdown]
# Hints:
#
# - Start by inspecting the website in your browser. Figure out which elements will be useful.
# - Start by creating a function that handles a single article and produces a dictionary like the one above.
# - Next create a function that will find all the articles on a single page and call the function you created in the last step for every article on the page.
# - Now create a function that will use the previous two functions to scrape the articles from all the pages that you need, and do any additional processing that needs to be done.

# %%
url = 'https://inshorts.com/en/read'

headers = {'User-Agent': 'Codeup Data Science'}
response = get(url, headers=headers)
soup = BeautifulSoup(response.content, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE doctype html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <style>
#    /* The Modal (background) */
#     .modal_contact {
#         display: none; /* Hidden by default */
#         position: fixed; /* Stay in place */
#         z-index: 8; /* Sit on top */
#         left: 0;
#         top: 0;
#         width: 100%; /* Full width */
#         height: 100%;
#         overflow: auto; /* Enable scroll if needed */
#         background-color: rgb(0,0,0); /* Fallback color */
#         background-color: rgba(0,0,0,0.4); /* Black w/ opacity */
#     }
#
#     /* Modal Content/Box */
#     .modal-content {
#         background-color: #fefefe;
#         margin: 15% auto;
#         padding: 20px !important;
#         padding-top: 0 !important;
#         /* border: 1px solid #888; */
#         text-align: center;
#         position: relative;
#         border-radius: 6px;
#     }
#
#     /* The Close Button */
#     .close {
#       left: 90%;
#       color: #aaa;
#       float: right;
#       font-size: 28px;
#       font-weight: bold;
#     /* position: absolute; */
#     /* bottom: 86%; */
#     /* display: inline-block; */
#     /* padding-left: 5%; */
#     }
#
#     .close:hover,
#     .close:focus {
#         color: black;
#         text-decoration: none;
#         cursor: pointer;
#     }
#
#     #myBtn {
#       background: #999999;
#       color: #ffffff;
#       text-transform: uppercase;
#       font-weight: bold;
#       box-shadow: none;
#       border-radius: 4px;
#       border: none;
#       font-size: .8rem;
#       /* width: 8rem; */
#       height: 2rem;
#       line-height: 2rem;
#     }
#
#     .contact {
#       margin-bottom: 4%;
#       clear: both;
#     }
#   </style>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="width=device-width, initial-scale=1, maximum-scale=1.0, user-scalable=no" name="viewport"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <link href="manifest.json" rel="manifest"/>
#   <!-- Fallback to homescreen for Chrome   <39 on Android -->
#   <meta content="yes" name="mobile-web-app-capable"/>
#   <meta content="inshorts" name="application-name"/>
#   <link href="https://assets.inshorts.com/website_assets/images/favicon.png" rel="icon" sizes="192x192"/>
#   <!-- Add to homescreen for Safari on iOS -->
#   <meta content="yes" name="apple-mobile-web-app-capable"/>
#   <meta content="#424242" name="apple-mobile-web-app-status-bar-style"/>
#   <meta content="inshorts" name="apple-mobile-web-app-title"/>
#   <link href="https://assets.inshorts.com/website_assets/images/favicon.png" rel="apple-touch-icon"/>
#   <!-- Tile icon for Win8 (144x144 + tile color) -->
#   <meta content="fav/favicon.png" name="msapplication-TileImage"/>
#   <meta content="#424242" name="msapplication-TileColor"/>
#   <meta content="#424242" name="theme-color"/>
#   <meta content="text/html; charset=utf-8" http-equiv="content-type">
#    <meta content="#424242" name="msapplication-navbutton-color"/>
#    <meta content="#424242" name="apple-mobile-web-app-status-bar-style"/>
#    <link href="https://assets.inshorts.com/website_assets/images/favicon.png" rel="apple-touch-startup-image"/>
#    <meta content="black-translucent" name="apple-mobile-web-app-status-bar-style"/>
#    <meta content="app" name="twitter:card">
#     <meta content="@inshorts" name="twitter:site">
#      <meta content="@inshorts" name="twitter:creator">
#       <meta content="Inshorts delivers news in less than 60 words, containing only the essential facts, compromising on anything that is close to opinionating and storytelling." name="twitter:description">
#        <meta content="IN" name="twitter:app:country">
#         <meta content="Inshorts - Stay Informed" name="twitter:app:name:iphone">
#          <meta content="892146527" name="twitter:app:id:iphone">
#           <meta content="nis://news" name="twitter:app:url:iphone">
#            <meta content="Inshorts - Stay Informed" name="twitter:app:name:ipad">
#             <meta content="892146527" name="twitter:app:id:ipad">
#              <meta content="nis://news" name="twitter:app:url:ipad">
#               <meta content="Inshorts - Stay Informed" name="twitter:app:name:googleplay"/>
#               <meta content="com.nis.app" name="twitter:app:id:googleplay"/>
#               <meta content="nis://news" name="twitter:app:url:googleplay"/>
#               <meta content="Read short news updates in less than 60 words with inshorts. All daily news updates related to business, sports, technology, India, world and entertainment in English with inshorts" name="description"/>
#               <link href="https://inshorts.com/en/read/" rel="canonical">
#                <link href="https://inshorts.com/en/read/" reflang="en" rel="alternate">
#                 <meta content="app-id=892146527" name="apple-itunes-app"/>
#                 <meta content="app-id=com.nis.app" name="google-play-app"/>
#                 <title>
#                  Breaking News Headlines: Read All News Updates in English | Inshorts
#                 </title>
#                 <!-- CSS  -->
#                 <link href="https://fonts.googleapis.com/css?family=Roboto" rel="stylesheet" type="text/css"/>
#                 <link href="https://fonts.googleapis.com/icon?family=Material+Icons" rel="stylesheet"/>
#                 <link href="https://cdnjs.cloudflare.com/ajax/libs/materialize/0.97.1/css/materialize.min.css" rel="stylesheet"/>
#                 <link href="https://fonts.googleapis.com/css?family=Hind:500,600,400&amp;subset=latin,devanagari" rel="stylesheet" type="text/css"/>
#                 <link href="/dist/styles/main.css" media="screen,projection" rel="stylesheet" type="text/css">
#                  <link href="/dist/styles/index.css" media="screen,projection" rel="stylesheet" type="text/css">
#                   <link href="/dist/styles/read.css" media="screen,projection" rel="stylesheet" type="text/css">
#                    <link href="/dist/styles/news-card.css" media="screen,projection" rel="stylesheet" type="text/css">
#                     <link href="https://assets.inshorts.com/website_assets/images/favicon.png" rel="icon" type="image/png">
#                      <link href="/dist/manifest.json" rel="manifest"/>
#                      <script async="async" src="https://www.googletagservices.com/tag/js/gpt.js">
#                      </script>
#                      <script>
#                       var googletag = googletag || {};
#     googletag.cmd = googletag.cmd || [];
#     let top_banner_slot;
#                      </script>
#                      <!-- Top banner for desktop-->
#                      <script>
#                       googletag.cmd.push(function() {
#
#
#         //Top banner for desktop
#         top_banner_slot = googletag.defineSlot('/142919096/inshorts_website_728x90', [728, 90], 'div-gpt-ad-1536585015617-0')
#         .addService(googletag.pubads())
#         .setCollapseEmptyDiv(true,true);
#
#
#       googletag.pubads().disableInitialLoad();
#       googletag.pubads().enableSingleRequest();
#       googletag.enableServices();
#     });
#                      </script>
#                      <!-- Facebook Pixel Code -->
#                      <script>
#                       !function(f,b,e,v,n,t,s)
#     {if(f.fbq)return;n=f.fbq=function(){n.callMethod?
#     n.callMethod.apply(n,arguments):n.queue.push(arguments)};
#     if(!f._fbq)f._fbq=n;n.push=n;n.loaded=!0;n.version='2.0';
#     n.queue=[];t=b.createElement(e);t.async=!0;
#     t.src=v;s=b.getElementsByTagName(e)[0];
#     s.parentNode.insertBefore(t,s)}(window, document,'script',
#     'https://connect.facebook.net/en_US/fbevents.js');
#     fbq('init', '822966517773327');
#     fbq('track', 'PageView');
#                      </script>
#                      <noscript>
#                       <img height="1" src="https://www.facebook.com/tr?id=822966517773327&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/>
#                      </noscript>
#                      <!-- End Facebook Pixel Code -->
#                     </link>
#                    </link>
#                   </link>
#                  </link>
#                 </link>
#                </link>
#               </link>
#              </meta>
#             </meta>
#            </meta>
#           </meta>
#          </meta>
#         </meta>
#        </meta>
#       </meta>
#      </meta>
#     </meta>
#    </meta>
#   </meta>
#  </head>
#  <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-55157535-6', 'auto');
#   ga('send', 'pageview');
#  </script>
#  <body>
#   <!-- Begin comScore Tag -->
#   <script>
#    var _comscore = _comscore || [];
#     _comscore.push({ c1: "2", c2: "28268321" });
#     (function() {
#       var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true;
#       s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js";
#       el.parentNode.insertBefore(s, el);
#     })();
#   </script>
#   <noscript>
#    <img src="https://sb.scorecardresearch.com/p?c1=2&amp;c2=28268321&amp;cv=2.0&amp;cj=1"/>
#   </noscript>
#   <!-- HEADER START -->
#   <div class="header z-depth-1">
#    <div class="menu clickable">
#     <button class="c-hamburger c-hamburger--htx">
#      <span>
#       toggle menu
#      </span>
#     </button>
#     <span class="unselectable">
#      Menu
#     </span>
#    </div>
#    <!--
#     <div class="search-wrapper hide-on-small-only">
#       <input class="search-box" placeholder="Search" id="search"/>
#       <i id="search_icon" class="material-icons search-icon">search</i>
#       <div class="search-box-ul">&nbsp;</div>
#     </div>
#     -->
#    <a href="/">
#     <img class="logo" src="https://assets.inshorts.com/website_assets/images/logo_inshorts.png"/>
#    </a>
#   </div>
#   <!-- HEADER END -->
#   <!--SIDEBAR START -->
#   <div class="hide-on-med-and-up sidebar-bg" style="display: none;">
#   </div>
#   <div class="sidebar" style="overflow-y: scroll;">
#    <div class="lang-bar" style="">
#     <div class="lang-selector clickable">
#      <a href="/en/read">
#       <div class="lang-en selected">
#        English
#       </div>
#      </a>
#      <a href="/hi/read">
#       <div class="lang-hi">
#        हिन्दी
#       </div>
#      </a>
#     </div>
#    </div>
#    <div>
#     <div class="category-header">
#      Categories
#     </div>
#     <ul class="category-list">
#      <a href="/en/read" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkToAllNews', 'eventAction': 'clicked', 'eventLabel': 'RedirectedToAllNews' });">
#       <li class="active-category selected">
#        All News
#       </li>
#      </a>
#      <a href="/en/read/national" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkToIndiaNews', 'eventAction': 'clicked', 'eventLabel': 'RedirectedToIndiaNews' });">
#       <li class="active-category">
#        India
#       </li>
#      </a>
#      <a "clicked",="" "event",="" "eventaction":="" "eventcategory":="" "eventlabel":="" "linktoindianews",="" "redirectedtoindianews"="" href="/en/read/business" onclick="ga(" send",="" {"hittype":="" });"="">
#       <li class="active-category">
#        Business
#       </li>
#      </a>
#      <a href="/en/read/sports" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkTosportsNews', 'eventAction': 'clicked', 'eventLabel': 'RedirectedToSportsNews' });">
#       <li class="active-category">
#        Sports
#       </li>
#      </a>
#      <a href="/en/read/world" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkToworldNews', 'eventAction': 'clicked', 'eventLabel': 'RedirectedToworldNews' });">
#       <li class="active-category">
#        World
#       </li>
#      </a>
#      <a href="/en/read/politics" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkToworldNews', 'eventAction': 'clicked',   'eventLabel': 'RedirectedToworldNews' });">
#       <li class="active-category">
#        Politics
#       </li>
#      </a>
#      <a href="/en/read/technology" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkTotechnologyNews', 'eventAction': 'clicked', 'eventLabel': 'RedirectedTotechnologyNews' });">
#       <li class="active-category">
#        Technology
#       </li>
#      </a>
#      <a href="/en/read/startup" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkTostartupNews', 'eventAction': 'clicked', 'eventLabel': 'RedirectedTostartupNews' });">
#       <li class="active-category">
#        Startup
#       </li>
#      </a>
#      <a href="/en/read/entertainment" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkToEntertainmentNews', 'eventAction': 'clicked', 'eventLabel': 'RedirectedToEntertainmentNews' });">
#       <li class="active-category">
#        Entertainment
#       </li>
#      </a>
#      <a href="/en/read/miscellaneous" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkToMiscellaneousNews', 'eventAction': 'clicked', 'eventLabel': 'RedirectedToMiscellaneousNews' });">
#       <li class="active-category">
#        Miscellaneous
#       </li>
#      </a>
#      <a href="/en/read/hatke" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkTohatkeNews', 'eventAction': 'clicked', 'eventLabel': 'RedirectedTohatkeNews' });">
#       <li class="active-category">
#        Hatke
#       </li>
#      </a>
#      <a href="/en/read/science" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkToscienceNews', 'eventAction': 'clicked', 'eventLabel': 'RedirectedToscienceNews' });">
#       <li class="active-category">
#        Science
#       </li>
#      </a>
#      <a href="/en/read/automobile" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkToautomobileNews', 'eventAction': 'clicked', 'eventLabel': 'RedirectedToautomobileNews' });">
#       <li class="active-category">
#        Automobile
#       </li>
#      </a>
#     </ul>
#    </div>
#   </div>
#   <!--SIDEBAR END -->
#   <!-- BODY START -->
#   <div class="container" style="min-height:550px;">
#    <div class="row" style="padding-top:110px;">
#     <div id="div-gpt-ad-1536585015617-0" style="height:90px; width:728px;margin: auto; margin-bottom: 1%;">
#      <script>
#       googletag.cmd.push(function() {
#             googletag.display('div-gpt-ad-1536585015617-0');
#             googletag.pubads().refresh([top_banner_slot]);
#           });
#      </script>
#     </div>
#     <div class="hide-on-med-and-down z-depth-1" style="margin-left : auto;margin-right : auto;margin-bottom: 32px;width : 900px;height:48px;background: #f44336">
#      <div style="font-weight: 300;color:white !important;font-size:14px;margin-left: 48px;margin-top: 13px;position: absolute;display: block;">
#       For the best experience use
#       <a href="https://inshorts.com/mobile" style="color:white;appearance: none;font-weight: 500;" target="_blank">
#        inshorts
#       </a>
#       app on your smartphone
#      </div>
#     </div>
#     <div class="card-stack">
#      <div class="">
#       <div class="news-card z-depth-1" itemscope="" itemtype="http://schema.org/NewsArticle">
#        <span content="" itemid="https://inshorts.com/en/news/69818-people-tested-for-coronavirus-in-punjab-so-far-confirmed-cases-reach-2106-1590515499904" itemprop="mainEntityOfPage" itemscope="" itemtype="https://schema.org/WebPage">
#        </span>
#        <span itemprop="author" itemscope="itemscope" itemtype="https://schema.org/Person">
#         <span content="Anmol Sharma" itemprop="name">
#         </span>
#        </span>
#        <span content="69,818 people tested for coronavirus in Punjab so far, confirmed cases reach 2,106" itemprop="description">
#        </span>
#        <span itemprop="image" itemscope="" itemtype="https://schema.org/ImageObject">
#         <meta content="https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2020/05_may/26_tue/img_1590514707814_503.jpg?" itemprop="url"/>
#         <meta content="864" itemprop="width"/>
#         <meta content="483" itemprop="height"/>
#        </span>
#        <span itemprop="publisher" itemscope="itemscope" itemtype="https://schema.org/Organization">
#         <span content="https://inshorts.com/" itemprop="url">
#         </span>
#         <span content="Inshorts" itemprop="name">
#         </span>
#         <span itemprop="logo" itemscope="" itemtype="https://schema.org/ImageObject">
#          <span content="https://assets.inshorts.com/inshorts/images/v1/variants/jpg/m/2018/11_nov/21_wed/img_1542823931298_497.jpg" itemprop="url">
#          </span>
#          <meta content="400" itemprop="width"/>
#          <meta content="60" itemprop="height"/>
#         </span>
#        </span>
#        <div class="news-card-image" style="background-image: url('https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2020/05_may/26_tue/img_1590514707814_503.jpg?')">
#        </div>
#        <div class="news-card-title news-right-box">
#         <a class="clickable" href="/en/news/69818-people-tested-for-coronavirus-in-punjab-so-far-confirmed-cases-reach-2106-1590515499904" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'TitleOfNews', 'eventAction': 'clicked', 'eventLabel': '69%2C818%20people%20tested%20for%20coronavirus%20in%20Punjab%20so%20far%2C%20confirmed%20cases%20reach%202%2C106)' });" style="color:#44444d!important">
#          <span itemprop="headline">
#           69,818 people tested for coronavirus in Punjab so far, confirmed cases reach 2,106
#          </span>
#         </a>
#         <div class="news-card-author-time news-card-author-time-in-title">
#          <a href="/prev/en/news/69818-people-tested-for-coronavirus-in-punjab-so-far-confirmed-cases-reach-2106-1590515499904">
#           <span class="short">
#            short
#           </span>
#          </a>
#          by
#          <span class="author">
#           Anmol Sharma
#          </span>
#          /
#          <span class="time" content="2020-05-26T17:51:39.000Z" itemprop="datePublished">
#           11:21 pm
#          </span>
#          on
#          <span clas="date">
#           26 May 2020,Tuesday
#          </span>
#         </div>
#        </div>
#        <div class="news-card-content news-right-box">
#         <div itemprop="articleBody">
#          As many as 69,818 people have been tested for coronavirus in Punjab so far, out of which 2,106 have tested positive. A total of 64,160 people have tested negative for the virus, while results of 3,552 people are awaited. Active number of cases stand at 148, while 40 deaths have been reported so far.
#         </div>
#         <div class="news-card-author-time news-card-author-time-in-content">
#          <a href="/prev/en/news/69818-people-tested-for-coronavirus-in-punjab-so-far-confirmed-cases-reach-2106-1590515499904">
#           <span class="short">
#            short
#           </span>
#          </a>
#          by
#          <span class="author">
#           Anmol Sharma
#          </span>
#          /
#          <span class="time" content="2020-05-26T17:51:39.000Z" itemprop="dateModified">
#           11:21 pm
#          </span>
#          on
#          <span class="date">
#           26 May
#          </span>
#         </div>
#        </div>
#        <div class="news-card-footer news-right-box">
#         <div class="read-more">
#          read more at
#          <a class="source" href="https://twitter.com/kbssidhu1961/status/1265298503560921088?utm_campaign=fullarticle&amp;utm_medium=referral&amp;utm_source=inshorts " onclick="ga('send', {'hitType': 'event', 'eventCategory': 'ReadMore', 'eventAction': 'clicked', 'eventLabel': 'Twitter' });" target="_blank">
#           Twitter
#          </a>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="">
#       <div class="news-card z-depth-1" itemscope="" itemtype="http://schema.org/NewsArticle">
#        <span content="" itemid="https://inshorts.com/en/news/nearly-100-coronavirus-deaths-reported-in-maharashtra-in-biggest-singleday-rise-so-far-1590512643592" itemprop="mainEntityOfPage" itemscope="" itemtype="https://schema.org/WebPage">
#        </span>
#        <span itemprop="author" itemscope="itemscope" itemtype="https://schema.org/Person">
#         <span content="Anmol Sharma" itemprop="name">
#         </span>
#        </span>
#        <span content="Nearly 100 coronavirus deaths reported in Maharashtra in biggest single-day rise so far" itemprop="description">
#        </span>
#        <span itemprop="image" itemscope="" itemtype="https://schema.org/ImageObject">
#         <meta content="https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2020/05_may/26_tue/img_1590511719903_94.jpg?" itemprop="url"/>
#         <meta content="864" itemprop="width"/>
#         <meta content="483" itemprop="height"/>
#        </span>
#        <span itemprop="publisher" itemscope="itemscope" itemtype="https://schema.org/Organization">
#         <span content="https://inshorts.com/" itemprop="url">
#         </span>
#         <span content="Inshorts" itemprop="name">
#         </span>
#         <span itemprop="logo" itemscope="" itemtype="https://schema.org/ImageObject">
#          <span content="https://assets.inshorts.com/inshorts/images/v1/variants/jpg/m/2018/11_nov/21_wed/img_1542823931298_497.jpg" itemprop="url">
#          </span>
#          <meta content="400" itemprop="width"/>
#          <meta content="60" itemprop="height"/>
#         </span>
#        </span>
#        <div class="news-card-image" style="background-image: url('https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2020/05_may/26_tue/img_1590511719903_94.jpg?')">
#        </div>
#        <div class="news-card-title news-right-box">
#         <a class="clickable" href="/en/news/nearly-100-coronavirus-deaths-reported-in-maharashtra-in-biggest-singleday-rise-so-far-1590512643592" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'TitleOfNews', 'eventAction': 'clicked', 'eventLabel': 'Nearly%20100%20coronavirus%20deaths%20reported%20in%20Maharashtra%20in%20biggest%20single-day%20rise%20so%20far)' });" style="color:#44444d!important">
#          <span itemprop="headline">
#           Nearly 100 coronavirus deaths reported in Maharashtra in biggest single-day rise so far
#          </span>
#         </a>
#         <div class="news-card-author-time news-card-author-time-in-title">
#          <a href="/prev/en/news/nearly-100-coronavirus-deaths-reported-in-maharashtra-in-biggest-singleday-rise-so-far-1590512643592">
#           <span class="short">
#            short
#           </span>
#          </a>
#          by
#          <span class="author">
#           Anmol Sharma
#          </span>
#          /
#          <span class="time" content="2020-05-26T17:04:03.000Z" itemprop="datePublished">
#           10:34 pm
#          </span>
#          on
#          <span clas="date">
#           26 May 2020,Tuesday
#          </span>
#         </div>
#        </div>
#        <div class="news-card-content news-right-box">
#         <div itemprop="articleBody">
#          As many as 97 coronavirus patients were reported dead in Maharashtra today, marking the biggest single-day rise in the number of deaths in the state so far. The death toll in Maharashtra rose to 1,792, while the total number of cases rose to 54,758 after 2,091 cases were reported today. A total of 3,90,170 tests have been conducted in Maharashtra.
#         </div>
#         <div class="news-card-author-time news-card-author-time-in-content">
#          <a href="/prev/en/news/nearly-100-coronavirus-deaths-reported-in-maharashtra-in-biggest-singleday-rise-so-far-1590512643592">
#           <span class="short">
#            short
#           </span>
#          </a>
#          by
#          <span class="author">
#           Anmol Sharma
#          </span>
#          /
#          <span class="time" content="2020-05-26T17:04:03.000Z" itemprop="dateModified">
#           10:34 pm
#          </span>
#          on
#          <span class="date">
#           26 May
#          </span>
#         </div>
#        </div>
#        <div class="news-card-footer news-right-box">
#         <div class="read-more">
#          read more at
#          <a class="source" href="https://twitter.com/micnewdelhi/status/1265303933326700546?utm_campaign=fullarticle&amp;utm_medium=referral&amp;utm_source=inshorts " onclick="ga('send', {'hitType': 'event', 'eventCategory': 'ReadMore', 'eventAction': 'clicked', 'eventLabel': 'MIC' });" target="_blank">
#           MIC
#          </a>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="">
#       <div class="news-card z-depth-1" itemscope="" itemtype="http://schema.org/NewsArticle">
#        <span content="" itemid="https://inshorts.com/en/news/gurugram-reports-33-new-coronavirus-cases-total-no-of-cases-rises-to-317-1590513201827" itemprop="mainEntityOfPage" itemscope="" itemtype="https://schema.org/WebPage">
#        </span>
#        <span itemprop="author" itemscope="itemscope" itemtype="https://schema.org/Person">
#         <span content="Apaar Sharma" itemprop="name">
#         </span>
#        </span>
#        <span content="Gurugram reports 33 new coronavirus cases, total no. of cases rises to 317" itemprop="description">
#        </span>
#        <span itemprop="image" itemscope="" itemtype="https://schema.org/ImageObject">
#         <meta content="https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2020/05_may/26_tue/img_1590511282810_873.jpg?" itemprop="url"/>
#         <meta content="864" itemprop="width"/>
#         <meta content="483" itemprop="height"/>
#        </span>
#        <span itemprop="publisher" itemscope="itemscope" itemtype="https://schema.org/Organization">
#         <span content="https://inshorts.com/" itemprop="url">
#         </span>
#         <span content="Inshorts" itemprop="name">
#         </span>
#         <span itemprop="logo" itemscope="" itemtype="https://schema.org/ImageObject">
#          <span content="https://assets.inshorts.com/inshorts/images/v1/variants/jpg/m/2018/11_nov/21_wed/img_1542823931298_497.jpg" itemprop="url">
#          </span>
#          <meta content="400" itemprop="width"/>
#          <meta content="60" itemprop="height"/>
#         </span>
#        </span>
#        <div class="news-card-image" style="background-image: url('https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2020/05_may/26_tue/img_1590511282810_873.jpg?')">
#        </div>
#        <div class="news-card-title news-right-box">
#         <a class="clickable" href="/en/news/gurugram-reports-33-new-coronavirus-cases-total-no-of-cases-rises-to-317-1590513201827" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'TitleOfNews', 'eventAction': 'clicked', 'eventLabel': 'Gurugram%20reports%2033%20new%20coronavirus%20cases%2C%20total%20no.%20of%20cases%20rises%20to%20317)' });" style="color:#44444d!important">
#          <span itemprop="headline">
#           Gurugram reports 33 new coronavirus cases, total no. of cases rises to 317
#          </span>
#         </a>
#         <div class="news-card-author-time news-card-author-time-in-title">
#          <a href="/prev/en/news/gurugram-reports-33-new-coronavirus-cases-total-no-of-cases-rises-to-317-1590513201827">
#           <span class="short">
#            short
#           </span>
#          </a>
#          by
#          <span class="author">
#           Apaar Sharma
#          </span>
#          /
#          <span class="time" content="2020-05-26T17:13:21.000Z" itemprop="datePublished">
#           10:43 pm
#          </span>
#          on
#          <span clas="date">
#           26 May 2020,Tuesday
#          </span>
#         </div>
#        </div>
#        <div class="news-card-content news-right-box">
#         <div itemprop="articleBody">
#          Haryana's Gurugram reported 33 new coronavirus cases on Tuesday, taking the total number of cases in the district to 317. A total of 183 COVID-19 patients have been discharged from hospitals, bringing down the total number of active cases to 134. Gurugram has sent over 12,000 samples to test for coronavirus, out of which reports of 200 samples are awaited.
#         </div>
#         <div class="news-card-author-time news-card-author-time-in-content">
#          <a href="/prev/en/news/gurugram-reports-33-new-coronavirus-cases-total-no-of-cases-rises-to-317-1590513201827">
#           <span class="short">
#            short
#           </span>
#          </a>
#          by
#          <span class="author">
#           Apaar Sharma
#          </span>
#          /
#          <span class="time" content="2020-05-26T17:13:21.000Z" itemprop="dateModified">
#           10:43 pm
#          </span>
#          on
#          <span class="date">
#           26 May
#          </span>
#         </div>
#        </div>
#        <div class="news-card-footer news-right-box">
#         <div class="read-more">
#          read more at
#          <a class="source" href="https://twitter.com/ANI/status/1265315809666068480?utm_campaign=fullarticle&amp;utm_medium=referral&amp;utm_source=inshorts " onclick="ga('send', {'hitType': 'event', 'eventCategory': 'ReadMore', 'eventAction': 'clicked', 'eventLabel': 'Twitter' });" target="_blank">
#           Twitter
#          </a>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="">
#       <div class="news-card z-depth-1" itemscope="" itemtype="http://schema.org/NewsArticle">
#        <span content="" itemid="https://inshorts.com/en/news/coronavirus-cases-in-rajasthan-cross-7500-death-toll-reaches-170-1590511291827" itemprop="mainEntityOfPage" itemscope="" itemtype="https://schema.org/WebPage">
#        </span>
#        <span itemprop="author" itemscope="itemscope" itemtype="https://schema.org/Person">
#         <span content="Apaar Sharma" itemprop="name">
#         </span>
#        </span>
#        <span content="Coronavirus cases in Rajasthan cross 7,500, death toll reaches 170" itemprop="description">
#        </span>
#        <span itemprop="image" itemscope="" itemtype="https://schema.org/ImageObject">
#         <meta content="https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2020/05_may/26_tue/img_1590510081540_139.jpg?" itemprop="url"/>
#         <meta content="864" itemprop="width"/>
#         <meta content="483" itemprop="height"/>
#        </span>
#        <span itemprop="publisher" itemscope="itemscope" itemtype="https://schema.org/Organization">
#         <span content="https://inshorts.com/" itemprop="url">
#         </span>
#         <span content="Inshorts" itemprop="name">
#         </span>
#         <span itemprop="logo" itemscope="" itemtype="https://schema.org/ImageObject">
#          <span content="https://assets.inshorts.com/inshorts/images/v1/variants/jpg/m/2018/11_nov/21_wed/img_1542823931298_497.jpg" itemprop="url">
#          </span>
#          <meta content="400" itemprop="width"/>
#          <meta content="60" itemprop="height"/>
#         </span>
#        </span>
#        <div class="news-card-image" style="background-image: url('https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2020/05_may/26_tue/img_1590510081540_139.jpg?')">
#        </div>
#        <div class="news-card-title news-right-box">
#         <a class="clickable" href="/en/news/coronavirus-cases-in-rajasthan-cross-7500-death-toll-reaches-170-1590511291827" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'TitleOfNews', 'eventAction': 'clicked', 'eventLabel': 'Coronavirus%20cases%20in%20Rajasthan%20cross%207%2C500%2C%20death%20toll%20reaches%20170)' });" style="color:#44444d!important">
#          <span itemprop="headline">
#           Coronavirus cases in Rajasthan cross 7,500, death toll reaches 170
#          </span>
#         </a>
#         <div class="news-card-author-time news-card-author-time-in-title">
#          <a href="/prev/en/news/coronavirus-cases-in-rajasthan-cross-7500-death-toll-reaches-170-1590511291827">
#           <span class="short">
#            short
#           </span>
#          </a>
#          by
#          <span class="author">
#           Apaar Sharma
#          </span>
#          /
#          <span class="time" content="2020-05-26T16:41:31.000Z" itemprop="datePublished">
#           10:11 pm
#          </span>
#          on
#          <span clas="date">
#           26 May 2020,Tuesday
#          </span>
#         </div>
#        </div>
#        <div class="news-card-content news-right-box">
#         <div itemprop="articleBody">
#          Rajasthan on Tuesday reported 236 cases of coronavirus, taking the total number of cases in the state to 7,536. The number of deaths due to COVID-19 touched 170 in the state after three more people died today. A total of 4,276 patients have, however, recovered from coronavirus in Rajasthan and 3,767 people have been discharged from hospitals across the state.
#         </div>
#         <div class="news-card-author-time news-card-author-time-in-content">
#          <a href="/prev/en/news/coronavirus-cases-in-rajasthan-cross-7500-death-toll-reaches-170-1590511291827">
#           <span class="short">
#            short
#           </span>
#          </a>
#          by
#          <span class="author">
#           Apaar Sharma
#          </span>
#          /
#          <span class="time" content="2020-05-26T16:41:31.000Z" itemprop="dateModified">
#           10:11 pm
#          </span>
#          on
#          <span class="date">
#           26 May
#          </span>
#         </div>
#        </div>
#        <div class="news-card-footer news-right-box">
#         <div class="read-more">
#          read more at
#          <a class="source" href="https://twitter.com/PIBJaipur/status/1265306790847102978?utm_campaign=fullarticle&amp;utm_medium=referral&amp;utm_source=inshorts " onclick="ga('send', {'hitType': 'event', 'eventCategory': 'ReadMore', 'eventAction': 'clicked', 'eventLabel': 'Twitter' });" target="_blank">
#           Twitter
#          </a>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div id="div-gpt-ad-1536748319959-ixmqfm76-1" style="height:250px; width:900px; margin: auto; margin-bottom: 2%;">
#       <script>
#        googletag.cmd.push(function() {
#           //News banner for desktop
#           var slotIdWeb = 'div-gpt-ad-1536748319959-ixmqfm76-1';
#           var slot = googletag.defineSlot('/142919096/inshorts_website_900x250', [900, 250], slotIdWeb)
#           .addService(googletag.pubads())
#           .setCollapseEmptyDiv(true,true);
#
#           googletag.display('div-gpt-ad-1536748319959-ixmqfm76-1');
#           googletag.pubads().refresh([slot]);
#         });
#       </script>
#      </div>
#      <div class="">
#       <div class="news-card z-depth-1" itemscope="" itemtype="http://schema.org/NewsArticle">
#        <span content="" itemid="https://inshorts.com/en/news/prepare-for-war-as-covid19-impacting-our-national-security-xi-to-chinese-army-1590511719128" itemprop="mainEntityOfPage" itemscope="" itemtype="https://schema.org/WebPage">
#        </span>
#        <span itemprop="author" itemscope="itemscope" itemtype="https://schema.org/Person">
#         <span content="Nandini Sinha" itemprop="name">
#         </span>
#        </span>
#        <span content="Prepare for war as COVID-19 impacting our national security: Xi to Chinese Army" itemprop="description">
#        </span>
#        <span itemprop="image" itemscope="" itemtype="https://schema.org/ImageObject">
#         <meta content="https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2020/05_may/26_tue/img_1590510416486_461.jpg?" itemprop="url"/>
#         <meta content="864" itemprop="width"/>
#         <meta content="483" itemprop="height"/>
#        </span>
#        <span itemprop="publisher" itemscope="itemscope" itemtype="https://schema.org/Organization">
#         <span content="https://inshorts.com/" itemprop="url">
#         </span>
#         <span content="Inshorts" itemprop="name">
#         </span>
#         <span itemprop="logo" itemscope="" itemtype="https://schema.org/ImageObject">
#          <span content="https://assets.inshorts.com/inshorts/images/v1/variants/jpg/m/2018/11_nov/21_wed/img_1542823931298_497.jpg" itemprop="url">
#          </span>
#          <meta content="400" itemprop="width"/>
#          <meta content="60" itemprop="height"/>
#         </span>
#        </span>
#        <div class="news-card-image" style="background-image: url('https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2020/05_may/26_tue/img_1590510416486_461.jpg?')">
#        </div>
#        <div class="news-card-title news-right-box">
#         <a class="clickable" href="/en/news/prepare-for-war-as-covid19-impacting-our-national-security-xi-to-chinese-army-1590511719128" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'TitleOfNews', 'eventAction': 'clicked', 'eventLabel': 'Prepare%20for%20war%20as%20COVID-19%20impacting%20our%20national%20security%3A%20Xi%20to%20Chinese%20Army)' });" style="color:#44444d!important">
#          <span itemprop="headline">
#           Prepare for war as COVID-19 impacting our national security: Xi to Chinese Army
#          </span>
#         </a>
#         <div class="news-card-author-time news-card-author-time-in-title">
#          <a href="/prev/en/news/prepare-for-war-as-covid19-impacting-our-national-security-xi-to-chinese-army-1590511719128">
#           <span class="short">
#            short
#           </span>
#          </a>
#          by
#          <span class="author">
#           Nandini Sinha
#          </span>
#          /
#          <span class="time" content="2020-05-26T16:48:39.000Z" itemprop="datePublished">
#           10:18 pm
#          </span>
#          on
#          <span clas="date">
#           26 May 2020,Tuesday
#          </span>
#         </div>
#        </div>
#        <div class="news-card-content news-right-box">
#         <div itemprop="articleBody">
#          Chinese President Xi Jinping on Tuesday directed China's Army to strengthen its training and prepare for war as coronavirus pandemic is having a profound impact on national security, the state media reported. Xi further said that the armed forces should explore new ways of training under the regular epidemic prevention and control situation.
#         </div>
#         <div class="news-card-author-time news-card-author-time-in-content">
#          <a href="/prev/en/news/prepare-for-war-as-covid19-impacting-our-national-security-xi-to-chinese-army-1590511719128">
#           <span class="short">
#            short
#           </span>
#          </a>
#          by
#          <span class="author">
#           Nandini Sinha
#          </span>
#          /
#          <span class="time" content="2020-05-26T16:48:39.000Z" itemprop="dateModified">
#           10:18 pm
#          </span>
#          on
#          <span class="date">
#           26 May
#          </span>
#         </div>
#        </div>
#        <div class="news-card-footer news-right-box">
#         <div class="read-more">
#          read more at
#          <a class="source" href="https://www.india.com/news/world/ladakh-standoff-xi-jinping-tells-chinese-military-to-scale-up-battle-preparedness-4040535/?utm_campaign=fullarticle&amp;utm_medium=referral&amp;utm_source=inshorts " onclick="ga('send', {'hitType': 'event', 'eventCategory': 'ReadMore', 'eventAction': 'clicked', 'eventLabel': 'India.com' });" target="_blank">
#           India.com
#          </a>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="">
#       <div class="news-card z-depth-1" itemscope="" itemtype="http://schema.org/NewsArticle">
#        <span content="" itemid="https://inshorts.com/en/news/russia-has-passed-its-peak-of-coronavirus-infections-putin-1590513490123" itemprop="mainEntityOfPage" itemscope="" itemtype="https://schema.org/WebPage">
#        </span>
#        <span itemprop="author" itemscope="itemscope" itemtype="https://schema.org/Person">
#         <span content="Shailesh" itemprop="name">
#         </span>
#        </span>
#        <span content="Russia has passed its peak of coronavirus infections: Putin" itemprop="description">
#        </span>
#        <span itemprop="image" itemscope="" itemtype="https://schema.org/ImageObject">
#         <meta content="https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2020/05_may/26_tue/img_1590510259668_797.jpg?" itemprop="url"/>
#         <meta content="864" itemprop="width"/>
#         <meta content="483" itemprop="height"/>
#        </span>
#        <span itemprop="publisher" itemscope="itemscope" itemtype="https://schema.org/Organization">
#         <span content="https://inshorts.com/" itemprop="url">
#         </span>
#         <span content="Inshorts" itemprop="name">
#         </span>
#         <span itemprop="logo" itemscope="" itemtype="https://schema.org/ImageObject">
#          <span content="https://assets.inshorts.com/inshorts/images/v1/variants/jpg/m/2018/11_nov/21_wed/img_1542823931298_497.jpg" itemprop="url">
#          </span>
#          <meta content="400" itemprop="width"/>
#          <meta content="60" itemprop="height"/>
#         </span>
#        </span>
#        <div class="news-card-image" style="background-image: url('https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2020/05_may/26_tue/img_1590510259668_797.jpg?')">
#        </div>
#        <div class="news-card-title news-right-box">
#         <a class="clickable" href="/en/news/russia-has-passed-its-peak-of-coronavirus-infections-putin-1590513490123" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'TitleOfNews', 'eventAction': 'clicked', 'eventLabel': 'Russia%20has%20passed%20its%20peak%20of%20coronavirus%20infections%3A%20Putin)' });" style="color:#44444d!important">
#          <span itemprop="headline">
#           Russia has passed its peak of coronavirus infections: Putin
#          </span>
#         </a>
#         <div class="news-card-author-time news-card-author-time-in-title">
#          <a href="/prev/en/news/russia-has-passed-its-peak-of-coronavirus-infections-putin-1590513490123">
#           <span class="short">
#            short
#           </span>
#          </a>
#          by
#          <span class="author">
#           Shailesh
#          </span>
#          /
#          <span class="time" content="2020-05-26T17:18:10.000Z" itemprop="datePublished">
#           10:48 pm
#          </span>
#          on
#          <span clas="date">
#           26 May 2020,Tuesday
#          </span>
#         </div>
#        </div>
#        <div class="news-card-content news-right-box">
#         <div itemprop="articleBody">
#          Russian President Vladimir Putin said that Russia has passed its peak of coronavirus infections and ordered the World War II victory parade postponed due to COVID-19 to be held in June. Russia on Tuesday reported 8,915 new coronavirus cases, lower than over 10,000 new cases per day being reported in recent days. Russia has reported over 3.62 lakh COVID-19 cases.
#         </div>
#         <div class="news-card-author-time news-card-author-time-in-content">
#          <a href="/prev/en/news/russia-has-passed-its-peak-of-coronavirus-infections-putin-1590513490123">
#           <span class="short">
#            short
#           </span>
#          </a>
#          by
#          <span class="author">
#           Shailesh
#          </span>
#          /
#          <span class="time" content="2020-05-26T17:18:10.000Z" itemprop="dateModified">
#           10:48 pm
#          </span>
#          on
#          <span class="date">
#           26 May
#          </span>
#         </div>
#        </div>
#        <div class="news-card-footer news-right-box">
#         <div class="read-more">
#          read more at
#          <a class="source" href="https://www.hindustantimes.com/world-news/putin-says-russia-passed-peak-of-coronavirus-epidemic-orders-world-war-ii-victory-parade/story-ppVthlasoEPyunLmAuj2RN.html?utm_campaign=fullarticle&amp;utm_medium=referral&amp;utm_source=inshorts " onclick="ga('send', {'hitType': 'event', 'eventCategory': 'ReadMore', 'eventAction': 'clicked', 'eventLabel': 'Hindustan%20Times' });" target="_blank">
#           Hindustan Times
#          </a>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="">
#       <div class="news-card z-depth-1" itemscope="" itemtype="http://schema.org/NewsArticle">
#        <span content="" itemid="https://inshorts.com/en/news/coronavirus-death-toll-in-uk-rises-to-37048-total-cases-surge-to-265227-1590516277588" itemprop="mainEntityOfPage" itemscope="" itemtype="https://schema.org/WebPage">
#        </span>
#        <span itemprop="author" itemscope="itemscope" itemtype="https://schema.org/Person">
#         <span content="Anmol Sharma" itemprop="name">
#         </span>
#        </span>
#        <span content="Coronavirus death toll in UK rises to 37,048, total cases surge to 265,227" itemprop="description">
#        </span>
#        <span itemprop="image" itemscope="" itemtype="https://schema.org/ImageObject">
#         <meta content="https://static.getinpix.com/public/images/v1/variants/jpg/m/2020/05_may/26_tue/img_1590503694441_254.jpg" itemprop="url"/>
#         <meta content="864" itemprop="width"/>
#         <meta content="483" itemprop="height"/>
#        </span>
#        <span itemprop="publisher" itemscope="itemscope" itemtype="https://schema.org/Organization">
#         <span content="https://inshorts.com/" itemprop="url">
#         </span>
#         <span content="Inshorts" itemprop="name">
#         </span>
#         <span itemprop="logo" itemscope="" itemtype="https://schema.org/ImageObject">
#          <span content="https://assets.inshorts.com/inshorts/images/v1/variants/jpg/m/2018/11_nov/21_wed/img_1542823931298_497.jpg" itemprop="url">
#          </span>
#          <meta content="400" itemprop="width"/>
#          <meta content="60" itemprop="height"/>
#         </span>
#        </span>
#        <div class="news-card-image" style="background-image: url('https://static.getinpix.com/public/images/v1/variants/jpg/m/2020/05_may/26_tue/img_1590503694441_254.jpg')">
#        </div>
#        <div class="news-card-title news-right-box">
#         <a class="clickable" href="/en/news/coronavirus-death-toll-in-uk-rises-to-37048-total-cases-surge-to-265227-1590516277588" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'TitleOfNews', 'eventAction': 'clicked', 'eventLabel': 'Coronavirus%20death%20toll%20in%20UK%20rises%20to%2037%2C048%2C%20total%20cases%20surge%20to%20265%2C227)' });" style="color:#44444d!important">
#          <span itemprop="headline">
#           Coronavirus death toll in UK rises to 37,048, total cases surge to 265,227
#          </span>
#         </a>
#         <div class="news-card-author-time news-card-author-time-in-title">
#          <a href="/prev/en/news/coronavirus-death-toll-in-uk-rises-to-37048-total-cases-surge-to-265227-1590516277588">
#           <span class="short">
#            short
#           </span>
#          </a>
#          by
#          <span class="author">
#           Anmol Sharma
#          </span>
#          /
#          <span class="time" content="2020-05-26T18:04:37.000Z" itemprop="datePublished">
#           11:34 pm
#          </span>
#          on
#          <span clas="date">
#           26 May 2020,Tuesday
#          </span>
#         </div>
#        </div>
#        <div class="news-card-content news-right-box">
#         <div itemprop="articleBody">
#          The death toll due to coronavirus in UK has surged to 37,048 after 134 new deaths were recorded in the last 24 hours. The total number of coronavirus cases in the UK has risen to 265,227 after 2,004 more people tested positive in the last 24 hours. A total of 3,681,295 tests have been conducted in the UK so far.
#         </div>
#         <div class="news-card-author-time news-card-author-time-in-content">
#          <a href="/prev/en/news/coronavirus-death-toll-in-uk-rises-to-37048-total-cases-surge-to-265227-1590516277588">
#           <span class="short">
#            short
#           </span>
#          </a>
#          by
#          <span class="author">
#           Anmol Sharma
#          </span>
#          /
#          <span class="time" content="2020-05-26T18:04:37.000Z" itemprop="dateModified">
#           11:34 pm
#          </span>
#          on
#          <span class="date">
#           26 May
#          </span>
#         </div>
#        </div>
#        <div class="news-card-footer news-right-box">
#         <div class="read-more">
#          read more at
#          <a class="source" href="https://twitter.com/DHSCgovuk/status/1265280074053382148?utm_campaign=fullarticle&amp;utm_medium=referral&amp;utm_source=inshorts " onclick="ga('send', {'hitType': 'event', 'eventCategory': 'ReadMore', 'eventAction': 'clicked', 'eventLabel': 'DHSC' });" target="_blank">
#           DHSC
#          </a>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="">
#       <div class="news-card z-depth-1" itemscope="" itemtype="http://schema.org/NewsArticle">
# ...
#         <span content="Kiran Khatri" itemprop="name">
#         </span>
#        </span>
#        <span content="Floods in Assam affect over 30,000 people in 5 districts" itemprop="description">
#        </span>
#        <span itemprop="image" itemscope="" itemtype="https://schema.org/ImageObject">
#         <meta content="https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2020/05_may/26_tue/img_1590512178255_21.jpg?" itemprop="url"/>
#         <meta content="864" itemprop="width"/>
#         <meta content="483" itemprop="height"/>
#        </span>
#        <span itemprop="publisher" itemscope="itemscope" itemtype="https://schema.org/Organization">
#         <span content="https://inshorts.com/" itemprop="url">
#         </span>
#         <span content="Inshorts" itemprop="name">
#         </span>
#         <span itemprop="logo" itemscope="" itemtype="https://schema.org/ImageObject">
#          <span content="https://assets.inshorts.com/inshorts/images/v1/variants/jpg/m/2018/11_nov/21_wed/img_1542823931298_497.jpg" itemprop="url">
#          </span>
#          <meta content="400" itemprop="width"/>
#          <meta content="60" itemprop="height"/>
#         </span>
#        </span>
#        <div class="news-card-image" style="background-image: url('https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2020/05_may/26_tue/img_1590512178255_21.jpg?')">
#        </div>
#        <div class="news-card-title news-right-box">
#         <a class="clickable" href="/en/news/floods-in-assam-affect-over-30000-people-in-5-districts-1590513860922" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'TitleOfNews', 'eventAction': 'clicked', 'eventLabel': 'Floods%20in%20Assam%20affect%20over%2030%2C000%20people%20in%205%20districts)' });" style="color:#44444d!important">
#          <span itemprop="headline">
#           Floods in Assam affect over 30,000 people in 5 districts
#          </span>
#         </a>
#         <div class="news-card-author-time news-card-author-time-in-title">
#          <a href="/prev/en/news/floods-in-assam-affect-over-30000-people-in-5-districts-1590513860922">
#           <span class="short">
#            short
#           </span>
#          </a>
#          by
#          <span class="author">
#           Kiran Khatri
#          </span>
#          /
#          <span class="time" content="2020-05-26T17:24:20.000Z" itemprop="datePublished">
#           10:54 pm
#          </span>
#          on
#          <span clas="date">
#           26 May 2020,Tuesday
#          </span>
#         </div>
#        </div>
#        <div class="news-card-content news-right-box">
#         <div itemprop="articleBody">
#          Over 30,000 people in five out of 33 districts in Assam have been impacted by heavy rains and floods in the state. According to the Assam State Disaster Management Authority (ASDMA), 128 villages in Lakhimpur, Dhemaji, Dibrugarh, Darrang and Goalpara districts have been affected. Nearly 9,000 people have been forced to take shelter in 33 relief camps in Goalpara.
#         </div>
#         <div class="news-card-author-time news-card-author-time-in-content">
#          <a href="/prev/en/news/floods-in-assam-affect-over-30000-people-in-5-districts-1590513860922">
#           <span class="short">
#            short
#           </span>
#          </a>
#          by
#          <span class="author">
#           Kiran Khatri
#          </span>
#          /
#          <span class="time" content="2020-05-26T17:24:20.000Z" itemprop="dateModified">
#           10:54 pm
#          </span>
#          on
#          <span class="date">
#           26 May
#          </span>
#         </div>
#        </div>
#        <div class="news-card-footer news-right-box">
#         <div class="read-more">
#          read more at
#          <a class="source" href="https://www.thequint.com/news/floods-hit-assam-amid-rising-covid-19-cases-alert-issued?utm_campaign=fullarticle&amp;utm_medium=referral&amp;utm_source=inshorts " onclick="ga('send', {'hitType': 'event', 'eventCategory': 'ReadMore', 'eventAction': 'clicked', 'eventLabel': 'The%20Quint' });" target="_blank">
#           The Quint
#          </a>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="">
#       <div class="news-card z-depth-1" itemscope="" itemtype="http://schema.org/NewsArticle">
#        <span content="" itemid="https://inshorts.com/en/news/israeli-court-considering-changing-location-of-pms-trial-reports-1590513632312" itemprop="mainEntityOfPage" itemscope="" itemtype="https://schema.org/WebPage">
#        </span>
#        <span itemprop="author" itemscope="itemscope" itemtype="https://schema.org/Person">
#         <span content="Shailesh" itemprop="name">
#         </span>
#        </span>
#        <span content="Israeli court considering changing location of PM's trial: Reports" itemprop="description">
#        </span>
#        <span itemprop="image" itemscope="" itemtype="https://schema.org/ImageObject">
#         <meta content="https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2020/05_may/26_tue/img_1590512079680_314.jpg?" itemprop="url"/>
#         <meta content="864" itemprop="width"/>
#         <meta content="483" itemprop="height"/>
#        </span>
#        <span itemprop="publisher" itemscope="itemscope" itemtype="https://schema.org/Organization">
#         <span content="https://inshorts.com/" itemprop="url">
#         </span>
#         <span content="Inshorts" itemprop="name">
#         </span>
#         <span itemprop="logo" itemscope="" itemtype="https://schema.org/ImageObject">
#          <span content="https://assets.inshorts.com/inshorts/images/v1/variants/jpg/m/2018/11_nov/21_wed/img_1542823931298_497.jpg" itemprop="url">
#          </span>
#          <meta content="400" itemprop="width"/>
#          <meta content="60" itemprop="height"/>
#         </span>
#        </span>
#        <div class="news-card-image" style="background-image: url('https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2020/05_may/26_tue/img_1590512079680_314.jpg?')">
#        </div>
#        <div class="news-card-title news-right-box">
#         <a class="clickable" href="/en/news/israeli-court-considering-changing-location-of-pms-trial-reports-1590513632312" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'TitleOfNews', 'eventAction': 'clicked', 'eventLabel': 'Israeli%20court%20considering%20changing%20location%20of%20PM's%20trial%3A%20Reports)' });" style="color:#44444d!important">
#          <span itemprop="headline">
#           Israeli court considering changing location of PM's trial: Reports
#          </span>
#         </a>
#         <div class="news-card-author-time news-card-author-time-in-title">
#          <a href="/prev/en/news/israeli-court-considering-changing-location-of-pms-trial-reports-1590513632312">
#           <span class="short">
#            short
#           </span>
#          </a>
#          by
#          <span class="author">
#           Shailesh
#          </span>
#          /
#          <span class="time" content="2020-05-26T17:20:32.000Z" itemprop="datePublished">
#           10:50 pm
#          </span>
#          on
#          <span clas="date">
#           26 May 2020,Tuesday
#          </span>
#         </div>
#        </div>
#        <div class="news-card-content news-right-box">
#         <div itemprop="articleBody">
#          Israeli court officials are considering changing the location of PM Benjamin Netanyahu's corruption trial due to the turmoil it caused by having to secure the site for the premier, media reports said. Netanyahu was required to attend the opening hearing of his trial at Jerusalem District Court on Sunday. Netanyahu became the first serving Israeli PM to go on trial.
#         </div>
#         <div class="news-card-author-time news-card-author-time-in-content">
#          <a href="/prev/en/news/israeli-court-considering-changing-location-of-pms-trial-reports-1590513632312">
#           <span class="short">
#            short
#           </span>
#          </a>
#          by
#          <span class="author">
#           Shailesh
#          </span>
#          /
#          <span class="time" content="2020-05-26T17:20:32.000Z" itemprop="dateModified">
#           10:50 pm
#          </span>
#          on
#          <span class="date">
#           26 May
#          </span>
#         </div>
#        </div>
#        <div class="news-card-footer news-right-box">
#         <div class="read-more">
#          read more at
#          <a class="source" href="https://www.india.com/news/world/israel-court-mulls-moving-benjamin-netanyahus-trial-to-new-location-4040537/?utm_campaign=fullarticle&amp;utm_medium=referral&amp;utm_source=inshorts " onclick="ga('send', {'hitType': 'event', 'eventCategory': 'ReadMore', 'eventAction': 'clicked', 'eventLabel': 'India.com' });" target="_blank">
#           India.com
#          </a>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="load-more-wrapper">
#      <div class="clickable unselectable load-more z-depth-1 hoverable" id="load-more-btn" onclick="loadMoreNews()">
#       Load More
#      </div>
#      <div class="clickable unselectable load-more" id="load-more-gif" style="display:none;">
#       <img id="load-more-gif" src="https://assets.inshorts.com/website_assets/images/ajax-loader.gif"/>
#      </div>
#     </div>
#     <div class="my-red app-download-pane hide-on-large-only">
#      <div class="container">
#       <div class="row">
#        <div class="col s12 center" style="color:white;font-weight: 300;font-size:14px;margin-top: 28px;margin-bottom: 18px;">
#         For the best experience use
#         <a href="/mobile" style="color:white;appearance: none;font-weight: 500;" target="_blank">
#          inshorts
#         </a>
#         app on your smartphone
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <!-- BODY END -->
#   <footer class="page-footer teals">
#    <div class="container">
#     <div class="row" style="margin-bottom: 0px; padding-bottom: 5px;">
#      <div class="col offset-l3 l3 m4 s12 right social-admin">
#       <div class="social-share">
#        <a href="https://www.facebook.com/inshortsapp" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkToFaceBookPage', 'eventAction': 'clicked', 'eventLabel': 'RedirectedToFaceBook' });" target="_blank">
#         <img src="https://assets.inshorts.com/website_assets/images/facebook.png"/>
#        </a>
#       </div>
#       <div class="social-share">
#        <a href="https://twitter.com/inshorts" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkToTwitterPage', 'eventAction': 'clicked', 'eventLabel': 'RedirectedToTwitter' });" target="_blank">
#         <img src="https://assets.inshorts.com/website_assets/images/twitter.png"/>
#        </a>
#       </div>
#       <div class="social-share">
#        <a href="https://www.linkedin.com/company/news-in-shorts" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkToLinkedinPage', 'eventAction': 'clicked', 'eventLabel': 'RedirectedToLinkedin' });" target="_blank">
#         <img src="https://assets.inshorts.com/website_assets/images/linkedin.png"/>
#        </a>
#       </div>
#      </div>
#      <div class="col m4 l3 s6 footer-left-pane">
#       <div class="right">
#        <img height="48px" src="https://assets.inshorts.com/website_assets/images/logo_footer.png" width="160px"/>
#       </div>
#       <div class="copy-text">
#        <span>
#         <span style="color:#cfcfcf;font-family: 'Conv_ClanPro-Bold'">
#          inshorts
#         </span>
#         medialabs pvt. ltd.
#        </span>
#        <br/>
#        ©
#        <span style="font-size:12px">
#         COPYRIGHT 2019
#        </span>
#       </div>
#      </div>
#      <div class="col m4 l3 s6 footer-right-pane">
#       <div class="left clickable" id="contactUsBtn" style="margin-top: -5px;">
#        <img height="48px" src="https://assets.inshorts.com/website_assets/images/contact_icon.png" width="132px"/>
#       </div>
#       <div class="terms-text">
#        <a class="tnc" href="/tnc" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkToTermsAndConditionsAndPP', 'eventAction': 'clicked', 'eventLabel': 'RedirectedToTermsAndConditions' });" style="color: #fff;" target="_blank">
#         <span>
#          Terms &amp; conditions
#         </span>
#         <br/>
#         <span>
#          Privacy Policies
#         </span>
#        </a>
#        <br/>
#        <a class="tnc" href="/editorial_policy" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkToSitemap', 'eventAction': 'clicked', 'eventLabel': 'RedirectedToSitemap' });" style="color: #fff;" target="_blank">
#         <span>
#          Editorial Policy
#         </span>
#        </a>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="modal_contact row" id="contactUsModal">
#     <!-- Modal content -->
#     <div class="modal-content col l4 m4 s8 offset-s2 offset-l4 offset-m4">
#      <span class="close">
#       ×
#      </span>
#      <div class="contact">
#       <a href="mailto:careers@inshorts.com?subject=Inshorts%20website%20contact%20form" target="_blank">
#        <button id="myBtn">
#         Contact Hiring Team
#        </button>
#       </a>
#      </div>
#      <div class="contact">
#       <a href="mailto:Admin@inshorts.com?subject=Inshorts%20website%20contact%20form" target="_blank">
#        <button id="myBtn">
#         Contact Admin Team
#        </button>
#       </a>
#      </div>
#      <div class="contact">
#       <a href="mailto:Marketing@inshorts.com?subject=Inshorts%20website%20contact%20form" target="_blank">
#        <button id="myBtn">
#         Contact Marketing Team
#        </button>
#       </a>
#      </div>
#      <div class="contact">
#       <a href="mailto:Editorial@inshorts.com?subject=Inshorts%20website%20contact%20form" target="_blank">
#        <button id="myBtn">
#         Contact Editorial Team
#        </button>
#       </a>
#      </div>
#      <div class="contact">
#       <a href="mailto:Sales@inshorts.com?subject=Inshorts%20website%20contact%20form" target="_blank">
#        <button id="myBtn">
#         Contact Sales Team
#        </button>
#       </a>
#      </div>
#      <div class="contact">
#       <a href="mailto:Contact@inshorts.com?subject=Inshorts%20website%20contact%20form" target="_blank">
#        <button id="myBtn">
#         Contact For Any Other Query
#        </button>
#       </a>
#      </div>
#     </div>
#    </div>
#   </footer>
#   <script>
#    var modal = document.getElementById('contactUsModal');
#
# // Get the button that opens the modal
# var btn = document.getElementById("contactUsBtn");
#
# // Get the <span> element that closes the modal
# var span = document.getElementsByClassName("close")[0];
#
# // When the user clicks on the button, open the modal
# btn.onclick = function() {
#     modal.style.display = "block";
# }
#
# // When the user clicks on <span> (x), close the modal
# span.onclick = function() {
#     modal.style.display = "none";
# }
#
# // When the user clicks anywhere outside of the modal, close it
# window.onclick = function(event) {
#     if (event.target == modal) {
#         modal.style.display = "none";
#     }
# }
#   </script>
#   <!-- Eliminate render-blocking JavaScript and CSS in above-the-fold content -->
#   <script src="https://ajax.googleapis.com/ajax/libs/jquery/1.8/jquery.min.js">
#   </script>
#   <script src="https://cdnjs.cloudflare.com/ajax/libs/materialize/0.97.0/js/materialize.min.js">
#   </script>
#   <script src="/dist/scripts/index.js" type="text/javascript">
#   </script>
#   <script src="/dist/scripts/read.js" type="text/javascript">
#   </script>
#   <script src="/dist/scripts/jquery.scrolldepth.min.js">
#   </script>
#   <script type="text/javascript">
#    var min_news_id = "jhnkmmet-1";
#     function loadMoreNews(){
#       $("#load-more-btn").hide();
#       $("#load-more-gif").show();
#       $.post("/en/ajax/more_news",{'category':'','news_offset':min_news_id},function(data){
#           data = JSON.parse(data);
#           min_news_id = data.min_news_id||min_news_id;
#           $(".card-stack").append(data.html);
#       })
#       .fail(function(){alert("Error : unable to load more news");})
#       .always(function(){$("#load-more-btn").show();$("#load-more-gif").hide();});
#     }
#     jQuery.scrollDepth();
#   </script>
#   <!-- Eliminate render-blocking JavaScript and CSS in above-the-fold content -->
#  </body>
# </html>

# %%
# A list of each card on the webpage, showing only the first
soup.find_all('div', class_="news-card")[0]
# Out:
# <div class="news-card z-depth-1" itemscope="" itemtype="http://schema.org/NewsArticle">
# <span content="" itemid="https://inshorts.com/en/news/69818-people-tested-for-coronavirus-in-punjab-so-far-confirmed-cases-reach-2106-1590515499904" itemprop="mainEntityOfPage" itemscope="" itemtype="https://schema.org/WebPage"></span>
# <span itemprop="author" itemscope="itemscope" itemtype="https://schema.org/Person">
# <span content="Anmol Sharma" itemprop="name"></span>
# </span>
# <span content="69,818 people tested for coronavirus in Punjab so far, confirmed cases reach 2,106" itemprop="description"></span>
# <span itemprop="image" itemscope="" itemtype="https://schema.org/ImageObject">
# <meta content="https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2020/05_may/26_tue/img_1590514707814_503.jpg?" itemprop="url"/>
# <meta content="864" itemprop="width"/>
# <meta content="483" itemprop="height"/>
# </span>
# <span itemprop="publisher" itemscope="itemscope" itemtype="https://schema.org/Organization">
# <span content="https://inshorts.com/" itemprop="url"></span>
# <span content="Inshorts" itemprop="name"></span>
# <span itemprop="logo" itemscope="" itemtype="https://schema.org/ImageObject">
# <span content="https://assets.inshorts.com/inshorts/images/v1/variants/jpg/m/2018/11_nov/21_wed/img_1542823931298_497.jpg" itemprop="url"></span>
# <meta content="400" itemprop="width"/>
# <meta content="60" itemprop="height"/>
# </span>
# </span>
# <div class="news-card-image" style="background-image: url('https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2020/05_may/26_tue/img_1590514707814_503.jpg?')">
# </div>
# <div class="news-card-title news-right-box">
# <a class="clickable" href="/en/news/69818-people-tested-for-coronavirus-in-punjab-so-far-confirmed-cases-reach-2106-1590515499904" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'TitleOfNews', 'eventAction': 'clicked', 'eventLabel': '69%2C818%20people%20tested%20for%20coronavirus%20in%20Punjab%20so%20far%2C%20confirmed%20cases%20reach%202%2C106)' });" style="color:#44444d!important">
# <span itemprop="headline">69,818 people tested for coronavirus in Punjab so far, confirmed cases reach 2,106</span>
# </a>
# <div class="news-card-author-time news-card-author-time-in-title">
# <a href="/prev/en/news/69818-people-tested-for-coronavirus-in-punjab-so-far-confirmed-cases-reach-2106-1590515499904"><span class="short">short</span></a> by <span class="author">Anmol Sharma</span> /
#       <span class="time" content="2020-05-26T17:51:39.000Z" itemprop="datePublished">11:21 pm</span> on <span clas="date">26 May 2020,Tuesday</span>
# </div>
# </div>
# <div class="news-card-content news-right-box">
# <div itemprop="articleBody">As many as 69,818 people have been tested for coronavirus in Punjab so far, out of which 2,106 have tested positive. A total of 64,160 people have tested negative for the virus, while results of 3,552 people are awaited. Active number of cases stand at 148, while 40 deaths have been reported so far.</div>
# <div class="news-card-author-time news-card-author-time-in-content">
# <a href="/prev/en/news/69818-people-tested-for-coronavirus-in-punjab-so-far-confirmed-cases-reach-2106-1590515499904"><span class="short">short</span></a> by <span class="author">Anmol Sharma</span> /
#       <span class="time" content="2020-05-26T17:51:39.000Z" itemprop="dateModified">11:21 pm</span> on <span class="date">26 May</span>
# </div>
# </div>
# <div class="news-card-footer news-right-box">
# <div class="read-more">read more at <a class="source" href="https://twitter.com/kbssidhu1961/status/1265298503560921088?utm_campaign=fullarticle&amp;utm_medium=referral&amp;utm_source=inshorts " onclick="ga('send', {'hitType': 'event', 'eventCategory': 'ReadMore', 'eventAction': 'clicked', 'eventLabel': 'Twitter' });" target="_blank">Twitter</a></div>
# </div>
# </div>

# %%
soup.find_all('span', itemprop="headline")[0].text
# Out:
# '69,818 people tested for coronavirus in Punjab so far, confirmed cases reach 2,106'

# %%
soup.find_all('div', itemprop="articleBody")[0].text
# Out:
# 'As many as 69,818 people have been tested for coronavirus in Punjab so far, out of which 2,106 have tested positive. A total of 64,160 people have tested negative for the virus, while results of 3,552 people are awaited. Active number of cases stand at 148, while 40 deaths have been reported so far.'

# %%
url = 'https://inshorts.com/en/read/business'

response = get(url)
soup = BeautifulSoup(response.content, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE doctype html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <style>
#    /* The Modal (background) */
#     .modal_contact {
#         display: none; /* Hidden by default */
#         position: fixed; /* Stay in place */
#         z-index: 8; /* Sit on top */
#         left: 0;
#         top: 0;
#         width: 100%; /* Full width */
#         height: 100%;
#         overflow: auto; /* Enable scroll if needed */
#         background-color: rgb(0,0,0); /* Fallback color */
#         background-color: rgba(0,0,0,0.4); /* Black w/ opacity */
#     }
#
#     /* Modal Content/Box */
#     .modal-content {
#         background-color: #fefefe;
#         margin: 15% auto;
#         padding: 20px !important;
#         padding-top: 0 !important;
#         /* border: 1px solid #888; */
#         text-align: center;
#         position: relative;
#         border-radius: 6px;
#     }
#
#     /* The Close Button */
#     .close {
#       left: 90%;
#       color: #aaa;
#       float: right;
#       font-size: 28px;
#       font-weight: bold;
#     /* position: absolute; */
#     /* bottom: 86%; */
#     /* display: inline-block; */
#     /* padding-left: 5%; */
#     }
#
#     .close:hover,
#     .close:focus {
#         color: black;
#         text-decoration: none;
#         cursor: pointer;
#     }
#
#     #myBtn {
#       background: #999999;
#       color: #ffffff;
#       text-transform: uppercase;
#       font-weight: bold;
#       box-shadow: none;
#       border-radius: 4px;
#       border: none;
#       font-size: .8rem;
#       /* width: 8rem; */
#       height: 2rem;
#       line-height: 2rem;
#     }
#
#     .contact {
#       margin-bottom: 4%;
#       clear: both;
#     }
#   </style>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="width=device-width, initial-scale=1, maximum-scale=1.0, user-scalable=no" name="viewport"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <link href="manifest.json" rel="manifest"/>
#   <!-- Fallback to homescreen for Chrome   <39 on Android -->
#   <meta content="yes" name="mobile-web-app-capable"/>
#   <meta content="inshorts" name="application-name"/>
#   <link href="https://assets.inshorts.com/website_assets/images/favicon.png" rel="icon" sizes="192x192"/>
#   <!-- Add to homescreen for Safari on iOS -->
#   <meta content="yes" name="apple-mobile-web-app-capable"/>
#   <meta content="#424242" name="apple-mobile-web-app-status-bar-style"/>
#   <meta content="inshorts" name="apple-mobile-web-app-title"/>
#   <link href="https://assets.inshorts.com/website_assets/images/favicon.png" rel="apple-touch-icon"/>
#   <!-- Tile icon for Win8 (144x144 + tile color) -->
#   <meta content="fav/favicon.png" name="msapplication-TileImage"/>
#   <meta content="#424242" name="msapplication-TileColor"/>
#   <meta content="#424242" name="theme-color"/>
#   <meta content="text/html; charset=utf-8" http-equiv="content-type">
#    <meta content="#424242" name="msapplication-navbutton-color"/>
#    <meta content="#424242" name="apple-mobile-web-app-status-bar-style"/>
#    <link href="https://assets.inshorts.com/website_assets/images/favicon.png" rel="apple-touch-startup-image"/>
#    <meta content="black-translucent" name="apple-mobile-web-app-status-bar-style"/>
#    <meta content="app" name="twitter:card">
#     <meta content="@inshorts" name="twitter:site">
#      <meta content="@inshorts" name="twitter:creator">
#       <meta content="Inshorts delivers news in less than 60 words, containing only the essential facts, compromising on anything that is close to opinionating and storytelling." name="twitter:description">
#        <meta content="IN" name="twitter:app:country">
#         <meta content="Inshorts - Stay Informed" name="twitter:app:name:iphone">
#          <meta content="892146527" name="twitter:app:id:iphone">
#           <meta content="nis://news" name="twitter:app:url:iphone">
#            <meta content="Inshorts - Stay Informed" name="twitter:app:name:ipad">
#             <meta content="892146527" name="twitter:app:id:ipad">
#              <meta content="nis://news" name="twitter:app:url:ipad">
#               <meta content="Inshorts - Stay Informed" name="twitter:app:name:googleplay"/>
#               <meta content="com.nis.app" name="twitter:app:id:googleplay"/>
#               <meta content="nis://news" name="twitter:app:url:googleplay"/>
#               <meta content="Read business news in English in less that 60 words and get updated with all India &amp; world news and current affairs in a fast and easy way with inshorts." name="description"/>
#               <link href="https://inshorts.com/en/read/business" rel="canonical">
#                <link href="https://inshorts.com/en/read/business" reflang="en" rel="alternate">
#                 <meta content="app-id=892146527" name="apple-itunes-app"/>
#                 <meta content="app-id=com.nis.app" name="google-play-app"/>
#                 <title>
#                  Business News: World and India Business News in English with Inshorts
#                 </title>
#                 <!-- CSS  -->
#                 <link href="https://fonts.googleapis.com/css?family=Roboto" rel="stylesheet" type="text/css"/>
#                 <link href="https://fonts.googleapis.com/icon?family=Material+Icons" rel="stylesheet"/>
#                 <link href="https://cdnjs.cloudflare.com/ajax/libs/materialize/0.97.1/css/materialize.min.css" rel="stylesheet"/>
#                 <link href="https://fonts.googleapis.com/css?family=Hind:500,600,400&amp;subset=latin,devanagari" rel="stylesheet" type="text/css"/>
#                 <link href="/dist/styles/main.css" media="screen,projection" rel="stylesheet" type="text/css">
#                  <link href="/dist/styles/index.css" media="screen,projection" rel="stylesheet" type="text/css">
#                   <link href="/dist/styles/read.css" media="screen,projection" rel="stylesheet" type="text/css">
#                    <link href="/dist/styles/news-card.css" media="screen,projection" rel="stylesheet" type="text/css">
#                     <link href="https://assets.inshorts.com/website_assets/images/favicon.png" rel="icon" type="image/png">
#                      <link href="/dist/manifest.json" rel="manifest"/>
#                      <script async="async" src="https://www.googletagservices.com/tag/js/gpt.js">
#                      </script>
#                      <script>
#                       var googletag = googletag || {};
#     googletag.cmd = googletag.cmd || [];
#     let top_banner_slot;
#                      </script>
#                      <!-- Top banner for desktop-->
#                      <script>
#                       googletag.cmd.push(function() {
#
#
#         //Top banner for desktop
#         top_banner_slot = googletag.defineSlot('/142919096/inshorts_website_728x90', [728, 90], 'div-gpt-ad-1536585015617-0')
#         .addService(googletag.pubads())
#         .setCollapseEmptyDiv(true,true);
#
#
#       googletag.pubads().disableInitialLoad();
#       googletag.pubads().enableSingleRequest();
#       googletag.enableServices();
#     });
#                      </script>
#                      <!-- Facebook Pixel Code -->
#                      <script>
#                       !function(f,b,e,v,n,t,s)
#     {if(f.fbq)return;n=f.fbq=function(){n.callMethod?
#     n.callMethod.apply(n,arguments):n.queue.push(arguments)};
#     if(!f._fbq)f._fbq=n;n.push=n;n.loaded=!0;n.version='2.0';
#     n.queue=[];t=b.createElement(e);t.async=!0;
#     t.src=v;s=b.getElementsByTagName(e)[0];
#     s.parentNode.insertBefore(t,s)}(window, document,'script',
#     'https://connect.facebook.net/en_US/fbevents.js');
#     fbq('init', '822966517773327');
#     fbq('track', 'PageView');
#                      </script>
#                      <noscript>
#                       <img height="1" src="https://www.facebook.com/tr?id=822966517773327&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/>
#                      </noscript>
#                      <!-- End Facebook Pixel Code -->
#                     </link>
#                    </link>
#                   </link>
#                  </link>
#                 </link>
#                </link>
#               </link>
#              </meta>
#             </meta>
#            </meta>
#           </meta>
#          </meta>
#         </meta>
#        </meta>
#       </meta>
#      </meta>
#     </meta>
#    </meta>
#   </meta>
#  </head>
#  <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-55157535-6', 'auto');
#   ga('send', 'pageview');
#  </script>
#  <body>
#   <!-- Begin comScore Tag -->
#   <script>
#    var _comscore = _comscore || [];
#     _comscore.push({ c1: "2", c2: "28268321" });
#     (function() {
#       var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true;
#       s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js";
#       el.parentNode.insertBefore(s, el);
#     })();
#   </script>
#   <noscript>
#    <img src="https://sb.scorecardresearch.com/p?c1=2&amp;c2=28268321&amp;cv=2.0&amp;cj=1"/>
#   </noscript>
#   <!-- HEADER START -->
#   <div class="header z-depth-1">
#    <div class="menu clickable">
#     <button class="c-hamburger c-hamburger--htx">
#      <span>
#       toggle menu
#      </span>
#     </button>
#     <span class="unselectable">
#      Menu
#     </span>
#    </div>
#    <!--
#     <div class="search-wrapper hide-on-small-only">
#       <input class="search-box" placeholder="Search" id="search"/>
#       <i id="search_icon" class="material-icons search-icon">search</i>
#       <div class="search-box-ul">&nbsp;</div>
#     </div>
#     -->
#    <a href="/">
#     <img class="logo" src="https://assets.inshorts.com/website_assets/images/logo_inshorts.png"/>
#    </a>
#   </div>
#   <!-- HEADER END -->
#   <!--SIDEBAR START -->
#   <div class="hide-on-med-and-up sidebar-bg" style="display: none;">
#   </div>
#   <div class="sidebar" style="overflow-y: scroll;">
#    <div class="lang-bar" style="">
#     <div class="lang-selector clickable">
#      <a href="/en/read/business">
#       <div class="lang-en selected">
#        English
#       </div>
#      </a>
#      <a href="/hi/read/business">
#       <div class="lang-hi">
#        हिन्दी
#       </div>
#      </a>
#     </div>
#    </div>
#    <div>
#     <div class="category-header">
#      Categories
#     </div>
#     <ul class="category-list">
#      <a href="/en/read" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkToAllNews', 'eventAction': 'clicked', 'eventLabel': 'RedirectedToAllNews' });">
#       <li class="active-category">
#        All News
#       </li>
#      </a>
#      <a href="/en/read/national" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkToIndiaNews', 'eventAction': 'clicked', 'eventLabel': 'RedirectedToIndiaNews' });">
#       <li class="active-category">
#        India
#       </li>
#      </a>
#      <a "clicked",="" "event",="" "eventaction":="" "eventcategory":="" "eventlabel":="" "linktoindianews",="" "redirectedtoindianews"="" href="/en/read/business" onclick="ga(" send",="" {"hittype":="" });"="">
#       <li class="active-category selected">
#        Business
#       </li>
#      </a>
#      <a href="/en/read/sports" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkTosportsNews', 'eventAction': 'clicked', 'eventLabel': 'RedirectedToSportsNews' });">
#       <li class="active-category">
#        Sports
#       </li>
#      </a>
#      <a href="/en/read/world" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkToworldNews', 'eventAction': 'clicked', 'eventLabel': 'RedirectedToworldNews' });">
#       <li class="active-category">
#        World
#       </li>
#      </a>
#      <a href="/en/read/politics" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkToworldNews', 'eventAction': 'clicked',   'eventLabel': 'RedirectedToworldNews' });">
#       <li class="active-category">
#        Politics
#       </li>
#      </a>
#      <a href="/en/read/technology" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkTotechnologyNews', 'eventAction': 'clicked', 'eventLabel': 'RedirectedTotechnologyNews' });">
#       <li class="active-category">
#        Technology
#       </li>
#      </a>
#      <a href="/en/read/startup" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkTostartupNews', 'eventAction': 'clicked', 'eventLabel': 'RedirectedTostartupNews' });">
#       <li class="active-category">
#        Startup
#       </li>
#      </a>
#      <a href="/en/read/entertainment" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkToEntertainmentNews', 'eventAction': 'clicked', 'eventLabel': 'RedirectedToEntertainmentNews' });">
#       <li class="active-category">
#        Entertainment
#       </li>
#      </a>
#      <a href="/en/read/miscellaneous" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkToMiscellaneousNews', 'eventAction': 'clicked', 'eventLabel': 'RedirectedToMiscellaneousNews' });">
#       <li class="active-category">
#        Miscellaneous
#       </li>
#      </a>
#      <a href="/en/read/hatke" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkTohatkeNews', 'eventAction': 'clicked', 'eventLabel': 'RedirectedTohatkeNews' });">
#       <li class="active-category">
#        Hatke
#       </li>
#      </a>
#      <a href="/en/read/science" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkToscienceNews', 'eventAction': 'clicked', 'eventLabel': 'RedirectedToscienceNews' });">
#       <li class="active-category">
#        Science
#       </li>
#      </a>
#      <a href="/en/read/automobile" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkToautomobileNews', 'eventAction': 'clicked', 'eventLabel': 'RedirectedToautomobileNews' });">
#       <li class="active-category">
#        Automobile
#       </li>
#      </a>
#     </ul>
#    </div>
#   </div>
#   <!--SIDEBAR END -->
#   <!-- BODY START -->
#   <div class="container" style="min-height:550px;">
#    <div class="row" style="padding-top:110px;">
#     <div id="div-gpt-ad-1536585015617-0" style="height:90px; width:728px;margin: auto; margin-bottom: 1%;">
#      <script>
#       googletag.cmd.push(function() {
#             googletag.display('div-gpt-ad-1536585015617-0');
#             googletag.pubads().refresh([top_banner_slot]);
#           });
#      </script>
#     </div>
#     <div class="hide-on-med-and-down z-depth-1" style="margin-left : auto;margin-right : auto;margin-bottom: 32px;width : 900px;height:48px;background: #f44336">
#      <div style="font-weight: 300;color:white !important;font-size:14px;margin-left: 48px;margin-top: 13px;position: absolute;display: block;">
#       For the best experience use
#       <a href="https://inshorts.com/mobile" style="color:white;appearance: none;font-weight: 500;" target="_blank">
#        inshorts
#       </a>
#       app on your smartphone
#      </div>
#     </div>
#     <div class="card-stack">
#      <div class="">
#       <div class="news-card z-depth-1" itemscope="" itemtype="http://schema.org/NewsArticle">
#        <span content="" itemid="https://inshorts.com/en/news/indias-economic-growth-seen-at-12-in-q4-fy20-sbi-report-1590496863509" itemprop="mainEntityOfPage" itemscope="" itemtype="https://schema.org/WebPage">
#        </span>
#        <span itemprop="author" itemscope="itemscope" itemtype="https://schema.org/Person">
#         <span content="Dharna" itemprop="name">
#         </span>
#        </span>
#        <span content="India's economic growth seen at 1.2% in Q4 FY20: SBI report" itemprop="description">
#        </span>
#        <span itemprop="image" itemscope="" itemtype="https://schema.org/ImageObject">
#         <meta content="https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2020/05_may/26_tue/img_1590491176727_950.jpg?" itemprop="url"/>
#         <meta content="864" itemprop="width"/>
#         <meta content="483" itemprop="height"/>
#        </span>
#        <span itemprop="publisher" itemscope="itemscope" itemtype="https://schema.org/Organization">
#         <span content="https://inshorts.com/" itemprop="url">
#         </span>
#         <span content="Inshorts" itemprop="name">
#         </span>
#         <span itemprop="logo" itemscope="" itemtype="https://schema.org/ImageObject">
#          <span content="https://assets.inshorts.com/inshorts/images/v1/variants/jpg/m/2018/11_nov/21_wed/img_1542823931298_497.jpg" itemprop="url">
#          </span>
#          <meta content="400" itemprop="width"/>
#          <meta content="60" itemprop="height"/>
#         </span>
#        </span>
#        <div class="news-card-image" style="background-image: url('https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2020/05_may/26_tue/img_1590491176727_950.jpg?')">
#        </div>
#        <div class="news-card-title news-right-box">
#         <a class="clickable" href="/en/news/indias-economic-growth-seen-at-12-in-q4-fy20-sbi-report-1590496863509" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'TitleOfNews', 'eventAction': 'clicked', 'eventLabel': 'India's%20economic%20growth%20seen%20at%201.2%25%20in%20Q4%20FY20%3A%20SBI%20report)' });" style="color:#44444d!important">
#          <span itemprop="headline">
#           India's economic growth seen at 1.2% in Q4 FY20: SBI report
#          </span>
#         </a>
#         <div class="news-card-author-time news-card-author-time-in-title">
#          <a href="/prev/en/news/indias-economic-growth-seen-at-12-in-q4-fy20-sbi-report-1590496863509">
#           <span class="short">
#            short
#           </span>
#          </a>
#          by
#          <span class="author">
#           Dharna
#          </span>
#          /
#          <span class="time" content="2020-05-26T12:41:03.000Z" itemprop="datePublished">
#           06:11 pm
#          </span>
#          on
#          <span clas="date">
#           26 May 2020,Tuesday
#          </span>
#         </div>
#        </div>
#        <div class="news-card-content news-right-box">
#         <div itemprop="articleBody">
#          India's economy is estimated to have grown at 1.2% for the quarter ended March 2020, said the SBI's Ecowrap report. It said the economic activity in the last seven days of March was completely suspended due to lockdown, causing an estimated loss of around ₹1.4 lakh crore. Subsequently, it projected the annual GDP growth for 2019-20 to be around 4.2%.
#         </div>
#         <div class="news-card-author-time news-card-author-time-in-content">
#          <a href="/prev/en/news/indias-economic-growth-seen-at-12-in-q4-fy20-sbi-report-1590496863509">
#           <span class="short">
#            short
#           </span>
#          </a>
#          by
#          <span class="author">
#           Dharna
#          </span>
#          /
#          <span class="time" content="2020-05-26T12:41:03.000Z" itemprop="dateModified">
#           06:11 pm
#          </span>
#          on
#          <span class="date">
#           26 May
#          </span>
#         </div>
#        </div>
#        <div class="news-card-footer news-right-box">
#         <div class="read-more">
#          read more at
#          <a class="source" href="https://www.deccanherald.com/business/business-news/coronavirus-lockdown-india-s-economy-could-contract-by-over-40-in-april-june-quarter-this-year-says-sbi-research-841926.html?utm_campaign=fullarticle&amp;utm_medium=referral&amp;utm_source=inshorts " onclick="ga('send', {'hitType': 'event', 'eventCategory': 'ReadMore', 'eventAction': 'clicked', 'eventLabel': 'Deccan%20Herald' });" target="_blank">
#           Deccan Herald
#          </a>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="">
#       <div class="news-card z-depth-1" itemscope="" itemtype="http://schema.org/NewsArticle">
#        <span content="" itemid="https://inshorts.com/en/news/glenmark-to-start-clinical-trial-to-test-potential-covid19-drug-combination-1590492153939" itemprop="mainEntityOfPage" itemscope="" itemtype="https://schema.org/WebPage">
#        </span>
#        <span itemprop="author" itemscope="itemscope" itemtype="https://schema.org/Person">
#         <span content="Krishna Veera Vanamali" itemprop="name">
#         </span>
#        </span>
#        <span content="Glenmark to start clinical trial to test potential COVID-19 drug combination" itemprop="description">
#        </span>
#        <span itemprop="image" itemscope="" itemtype="https://schema.org/ImageObject">
#         <meta content="https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2020/05_may/26_tue/img_1590490784740_507.jpg?" itemprop="url"/>
#         <meta content="864" itemprop="width"/>
#         <meta content="483" itemprop="height"/>
#        </span>
#        <span itemprop="publisher" itemscope="itemscope" itemtype="https://schema.org/Organization">
#         <span content="https://inshorts.com/" itemprop="url">
#         </span>
#         <span content="Inshorts" itemprop="name">
#         </span>
#         <span itemprop="logo" itemscope="" itemtype="https://schema.org/ImageObject">
#          <span content="https://assets.inshorts.com/inshorts/images/v1/variants/jpg/m/2018/11_nov/21_wed/img_1542823931298_497.jpg" itemprop="url">
#          </span>
#          <meta content="400" itemprop="width"/>
#          <meta content="60" itemprop="height"/>
#         </span>
#        </span>
#        <div class="news-card-image" style="background-image: url('https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2020/05_may/26_tue/img_1590490784740_507.jpg?')">
#        </div>
#        <div class="news-card-title news-right-box">
#         <a class="clickable" href="/en/news/glenmark-to-start-clinical-trial-to-test-potential-covid19-drug-combination-1590492153939" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'TitleOfNews', 'eventAction': 'clicked', 'eventLabel': 'Glenmark%20to%20start%20clinical%20trial%20to%20test%20potential%20COVID-19%20drug%20combination)' });" style="color:#44444d!important">
#          <span itemprop="headline">
#           Glenmark to start clinical trial to test potential COVID-19 drug combination
#          </span>
#         </a>
#         <div class="news-card-author-time news-card-author-time-in-title">
#          <a href="/prev/en/news/glenmark-to-start-clinical-trial-to-test-potential-covid19-drug-combination-1590492153939">
#           <span class="short">
#            short
#           </span>
#          </a>
#          by
#          <span class="author">
#           Krishna Veera Vanamali
#          </span>
#          /
#          <span class="time" content="2020-05-26T11:22:33.000Z" itemprop="datePublished">
#           04:52 pm
#          </span>
#          on
#          <span clas="date">
#           26 May 2020,Tuesday
#          </span>
#         </div>
#        </div>
#        <div class="news-card-content news-right-box">
#         <div itemprop="articleBody">
#          Glenmark Pharmaceuticals on Tuesday said it will begin a new clinical trial to test a combination of two antiviral drugs, favipiravir and umifenovir, as a potential COVID-19 treatment. The study will look to enrol 158 hospitalised patients suffering from moderate COVID-19 infections in India. Glenmark is already conducting clinical trials of just favipiravir as a potential COVID-19 treatment.
#         </div>
#         <div class="news-card-author-time news-card-author-time-in-content">
#          <a href="/prev/en/news/glenmark-to-start-clinical-trial-to-test-potential-covid19-drug-combination-1590492153939">
#           <span class="short">
#            short
#           </span>
#          </a>
#          by
#          <span class="author">
#           Krishna Veera Vanamali
#          </span>
#          /
#          <span class="time" content="2020-05-26T11:22:33.000Z" itemprop="dateModified">
#           04:52 pm
#          </span>
#          on
#          <span class="date">
#           26 May
#          </span>
#         </div>
#        </div>
#        <div class="news-card-footer news-right-box">
#         <div class="read-more">
#          read more at
#          <a class="source" href="https://www.deccanherald.com/science-and-environment/covid-19-glenmark-to-commence-clinical-trial-on-two-antiviral-drugs-combination-841967.html?utm_campaign=fullarticle&amp;utm_medium=referral&amp;utm_source=inshorts " onclick="ga('send', {'hitType': 'event', 'eventCategory': 'ReadMore', 'eventAction': 'clicked', 'eventLabel': 'Deccan%20Herald' });" target="_blank">
#           Deccan Herald
#          </a>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="">
#       <div class="news-card z-depth-1" itemscope="" itemtype="http://schema.org/NewsArticle">
#        <span content="" itemid="https://inshorts.com/en/news/uber-reduces-its-india-workforce-by-25-fires-600-employees-1590464141274" itemprop="mainEntityOfPage" itemscope="" itemtype="https://schema.org/WebPage">
#        </span>
#        <span itemprop="author" itemscope="itemscope" itemtype="https://schema.org/Person">
#         <span content="Dharna" itemprop="name">
#         </span>
#        </span>
#        <span content="Uber India fires 600 employees reducing 25% of its workforce" itemprop="description">
#        </span>
#        <span itemprop="image" itemscope="" itemtype="https://schema.org/ImageObject">
#         <meta content="https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2020/05_may/26_tue/img_1590461987341_33.jpg?" itemprop="url"/>
#         <meta content="864" itemprop="width"/>
#         <meta content="483" itemprop="height"/>
#        </span>
#        <span itemprop="publisher" itemscope="itemscope" itemtype="https://schema.org/Organization">
#         <span content="https://inshorts.com/" itemprop="url">
#         </span>
#         <span content="Inshorts" itemprop="name">
#         </span>
#         <span itemprop="logo" itemscope="" itemtype="https://schema.org/ImageObject">
#          <span content="https://assets.inshorts.com/inshorts/images/v1/variants/jpg/m/2018/11_nov/21_wed/img_1542823931298_497.jpg" itemprop="url">
#          </span>
#          <meta content="400" itemprop="width"/>
#          <meta content="60" itemprop="height"/>
#         </span>
#        </span>
#        <div class="news-card-image" style="background-image: url('https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2020/05_may/26_tue/img_1590461987341_33.jpg?')">
#        </div>
#        <div class="news-card-title news-right-box">
#         <a class="clickable" href="/en/news/uber-reduces-its-india-workforce-by-25-fires-600-employees-1590464141274" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'TitleOfNews', 'eventAction': 'clicked', 'eventLabel': 'Uber%20India%20fires%20600%20employees%20reducing%2025%25%20of%20its%20workforce)' });" style="color:#44444d!important">
#          <span itemprop="headline">
#           Uber India fires 600 employees reducing 25% of its workforce
#          </span>
#         </a>
#         <div class="news-card-author-time news-card-author-time-in-title">
#          <a href="/prev/en/news/uber-reduces-its-india-workforce-by-25-fires-600-employees-1590464141274">
#           <span class="short">
#            short
#           </span>
#          </a>
#          by
#          <span class="author">
#           Dharna
#          </span>
#          /
#          <span class="time" content="2020-05-26T03:35:41.000Z" itemprop="datePublished">
#           09:05 am
#          </span>
#          on
#          <span clas="date">
#           26 May 2020,Tuesday
#          </span>
#         </div>
#        </div>
#        <div class="news-card-content news-right-box">
#         <div itemprop="articleBody">
#          Uber is firing 600 employees in India, or 25% of its workforce in the country, amid the coronavirus pandemic. The layoffs, which are a part of Uber's global restructuring plan that eliminated 6,700 jobs, affect teams across customer and driver support, business development, legal, finance, policy and marketing verticals. Affected staff will be paid 10-12 weeks of salary, Uber said.
#         </div>
#         <div class="news-card-author-time news-card-author-time-in-content">
#          <a href="/prev/en/news/uber-reduces-its-india-workforce-by-25-fires-600-employees-1590464141274">
#           <span class="short">
#            short
#           </span>
#          </a>
#          by
#          <span class="author">
#           Dharna
#          </span>
#          /
#          <span class="time" content="2020-05-26T03:35:41.000Z" itemprop="dateModified">
#           09:05 am
#          </span>
#          on
#          <span class="date">
#           26 May
#          </span>
#         </div>
#        </div>
#        <div class="news-card-footer news-right-box">
#         <div class="read-more">
#          read more at
#          <a class="source" href="https://techcrunch.com/2020/05/25/uber-cuts-600-jobs-in-india/?utm_campaign=fullarticle&amp;utm_medium=referral&amp;utm_source=inshorts " onclick="ga('send', {'hitType': 'event', 'eventCategory': 'ReadMore', 'eventAction': 'clicked', 'eventLabel': 'TechCrunch' });" target="_blank">
#           TechCrunch
#          </a>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="">
#       <div class="news-card z-depth-1" itemscope="" itemtype="http://schema.org/NewsArticle">
#        <span content="" itemid="https://inshorts.com/en/news/tvs-motor-cuts-employees-salaries-by-up-to-20-for-six-months-1590476105082" itemprop="mainEntityOfPage" itemscope="" itemtype="https://schema.org/WebPage">
#        </span>
#        <span itemprop="author" itemscope="itemscope" itemtype="https://schema.org/Person">
#         <span content="Dharna" itemprop="name">
#         </span>
#        </span>
#        <span content="TVS Motor cuts employees' salaries by up to 20% for six months" itemprop="description">
#        </span>
#        <span itemprop="image" itemscope="" itemtype="https://schema.org/ImageObject">
#         <meta content="https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2020/05_may/26_tue/img_1590473228311_974.jpg?" itemprop="url"/>
#         <meta content="864" itemprop="width"/>
#         <meta content="483" itemprop="height"/>
#        </span>
#        <span itemprop="publisher" itemscope="itemscope" itemtype="https://schema.org/Organization">
#         <span content="https://inshorts.com/" itemprop="url">
#         </span>
#         <span content="Inshorts" itemprop="name">
#         </span>
#         <span itemprop="logo" itemscope="" itemtype="https://schema.org/ImageObject">
#          <span content="https://assets.inshorts.com/inshorts/images/v1/variants/jpg/m/2018/11_nov/21_wed/img_1542823931298_497.jpg" itemprop="url">
#          </span>
#          <meta content="400" itemprop="width"/>
#          <meta content="60" itemprop="height"/>
#         </span>
#        </span>
#        <div class="news-card-image" style="background-image: url('https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2020/05_may/26_tue/img_1590473228311_974.jpg?')">
#        </div>
#        <div class="news-card-title news-right-box">
#         <a class="clickable" href="/en/news/tvs-motor-cuts-employees-salaries-by-up-to-20-for-six-months-1590476105082" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'TitleOfNews', 'eventAction': 'clicked', 'eventLabel': 'TVS%20Motor%20cuts%20employees'%20salaries%20by%20up%20to%2020%25%20for%20six%20months)' });" style="color:#44444d!important">
#          <span itemprop="headline">
#           TVS Motor cuts employees' salaries by up to 20% for six months
#          </span>
#         </a>
#         <div class="news-card-author-time news-card-author-time-in-title">
#          <a href="/prev/en/news/tvs-motor-cuts-employees-salaries-by-up-to-20-for-six-months-1590476105082">
#           <span class="short">
#            short
#           </span>
#          </a>
#          by
#          <span class="author">
#           Dharna
#          </span>
#          /
#          <span class="time" content="2020-05-26T06:55:05.000Z" itemprop="datePublished">
#           12:25 pm
#          </span>
#          on
#          <span clas="date">
#           26 May 2020,Tuesday
#          </span>
#         </div>
#        </div>
#        <div class="news-card-content news-right-box">
#         <div itemprop="articleBody">
#          TVS Motor Company has said it is cutting the salaries of its employees for six months. Starting May, salaries will be reduced by 5% for junior executives, by 15-20% at senior management level and won't be cut at the workmen level. "It was heartening to see employees coming forward and offering to take salary reduction voluntarily," the two-wheeler maker said.
#         </div>
#         <div class="news-card-author-time news-card-author-time-in-content">
#          <a href="/prev/en/news/tvs-motor-cuts-employees-salaries-by-up-to-20-for-six-months-1590476105082">
#           <span class="short">
#            short
#           </span>
#          </a>
#          by
#          <span class="author">
#           Dharna
#          </span>
#          /
#          <span class="time" content="2020-05-26T06:55:05.000Z" itemprop="dateModified">
#           12:25 pm
#          </span>
#          on
#          <span class="date">
#           26 May
#          </span>
#         </div>
#        </div>
#        <div class="news-card-footer news-right-box">
#         <div class="read-more">
#          read more at
#          <a class="source" href="https://www.financialexpress.com/auto/industry/covid-19-effect-tvs-motor-company-announces-pay-cut-across-levels-for-six-months-coronavirus-india-lockdown-salary-job-losses-cases/1970721/?utm_campaign=fullarticle&amp;utm_medium=referral&amp;utm_source=inshorts " onclick="ga('send', {'hitType': 'event', 'eventCategory': 'ReadMore', 'eventAction': 'clicked', 'eventLabel': 'The%20Financial%20Express' });" target="_blank">
#           The Financial Express
#          </a>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div id="div-gpt-ad-1536748319959-giy6jqxi-1" style="height:250px; width:900px; margin: auto; margin-bottom: 2%;">
#       <script>
#        googletag.cmd.push(function() {
#           //News banner for desktop
#           var slotIdWeb = 'div-gpt-ad-1536748319959-giy6jqxi-1';
#           var slot = googletag.defineSlot('/142919096/inshorts_website_900x250', [900, 250], slotIdWeb)
#           .addService(googletag.pubads())
#           .setCollapseEmptyDiv(true,true);
#
#           googletag.display('div-gpt-ad-1536748319959-giy6jqxi-1');
#           googletag.pubads().refresh([slot]);
#         });
#       </script>
#      </div>
#      <div class="">
#       <div class="news-card z-depth-1" itemscope="" itemtype="http://schema.org/NewsArticle">
#        <span content="" itemid="https://inshorts.com/en/news/firm-whose-stock-surged-1000-in-2020-starts-human-trials-of-covid19-vaccine-1590488261204" itemprop="mainEntityOfPage" itemscope="" itemtype="https://schema.org/WebPage">
#        </span>
#        <span itemprop="author" itemscope="itemscope" itemtype="https://schema.org/Person">
#         <span content="Krishna Veera Vanamali" itemprop="name">
#         </span>
#        </span>
#        <span content="Firm whose stock surged 1000% in 2020 starts human trials of Covid-19 vaccine" itemprop="description">
#        </span>
#        <span itemprop="image" itemscope="" itemtype="https://schema.org/ImageObject">
#         <meta content="https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2020/05_may/26_tue/img_1590485470837_90.jpg?" itemprop="url"/>
#         <meta content="864" itemprop="width"/>
#         <meta content="483" itemprop="height"/>
#        </span>
#        <span itemprop="publisher" itemscope="itemscope" itemtype="https://schema.org/Organization">
#         <span content="https://inshorts.com/" itemprop="url">
#         </span>
#         <span content="Inshorts" itemprop="name">
#         </span>
#         <span itemprop="logo" itemscope="" itemtype="https://schema.org/ImageObject">
#          <span content="https://assets.inshorts.com/inshorts/images/v1/variants/jpg/m/2018/11_nov/21_wed/img_1542823931298_497.jpg" itemprop="url">
#          </span>
#          <meta content="400" itemprop="width"/>
#          <meta content="60" itemprop="height"/>
#         </span>
#        </span>
#        <div class="news-card-image" style="background-image: url('https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2020/05_may/26_tue/img_1590485470837_90.jpg?')">
#        </div>
#        <div class="news-card-title news-right-box">
#         <a class="clickable" href="/en/news/firm-whose-stock-surged-1000-in-2020-starts-human-trials-of-covid19-vaccine-1590488261204" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'TitleOfNews', 'eventAction': 'clicked', 'eventLabel': 'Firm%20whose%20stock%20surged%201000%25%20in%202020%20starts%20human%20trials%20of%20Covid-19%20vaccine)' });" style="color:#44444d!important">
#          <span itemprop="headline">
#           Firm whose stock surged 1000% in 2020 starts human trials of Covid-19 vaccine
#          </span>
#         </a>
#         <div class="news-card-author-time news-card-author-time-in-title">
#          <a href="/prev/en/news/firm-whose-stock-surged-1000-in-2020-starts-human-trials-of-covid19-vaccine-1590488261204">
#           <span class="short">
#            short
#           </span>
#          </a>
#          by
#          <span class="author">
#           Krishna Veera Vanamali
#          </span>
#          /
#          <span class="time" content="2020-05-26T10:17:41.000Z" itemprop="datePublished">
#           03:47 pm
#          </span>
#          on
#          <span clas="date">
#           26 May 2020,Tuesday
#          </span>
#         </div>
#        </div>
#        <div class="news-card-content news-right-box">
#         <div itemprop="articleBody">
#          US biotech company Novavax said it has started Phase 1 clinical trial of its experimental coronavirus vaccine and has enrolled 130 volunteers. Novavax's valuation has surged by over 1,000% this year to about $2.7 billion despite having no products on the market. The trial is being supported by $388 million in funding from the Coalition for Epidemic Preparedness Innovations (CEPI).
#         </div>
#         <div class="news-card-author-time news-card-author-time-in-content">
#          <a href="/prev/en/news/firm-whose-stock-surged-1000-in-2020-starts-human-trials-of-covid19-vaccine-1590488261204">
#           <span class="short">
#            short
#           </span>
#          </a>
#          by
#          <span class="author">
#           Krishna Veera Vanamali
#          </span>
#          /
#          <span class="time" content="2020-05-26T10:17:41.000Z" itemprop="dateModified">
#           03:47 pm
#          </span>
#          on
#          <span class="date">
#           26 May
#          </span>
#         </div>
#        </div>
#        <div class="news-card-footer news-right-box">
#         <div class="read-more">
#          read more at
#          <a class="source" href="https://www.deccanherald.com/science-and-environment/novavax-starts-phase-1-clinical-trial-of-coronavirus-vaccine-candidate-841923.html?utm_campaign=fullarticle&amp;utm_medium=referral&amp;utm_source=inshorts " onclick="ga('send', {'hitType': 'event', 'eventCategory': 'ReadMore', 'eventAction': 'clicked', 'eventLabel': 'Deccan%20Herald' });" target="_blank">
#           Deccan Herald
#          </a>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="">
#       <div class="news-card z-depth-1" itemscope="" itemtype="http://schema.org/NewsArticle">
#        <span content="" itemid="https://inshorts.com/en/news/lockdown-extensions-wont-help-cases-will-continue-to-rise-anand-mahindra-1590419311635" itemprop="mainEntityOfPage" itemscope="" itemtype="https://schema.org/WebPage">
#        </span>
#        <span itemprop="author" itemscope="itemscope" itemtype="https://schema.org/Person">
#         <span content="Anushka Dixit" itemprop="name">
#         </span>
#        </span>
#        <span content="Lockdown extensions won't help, cases will continue to rise: Anand Mahindra" itemprop="description">
#        </span>
#        <span itemprop="image" itemscope="" itemtype="https://schema.org/ImageObject">
#         <meta content="https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2020/05_may/25_mon/img_1590416653427_617.jpg?" itemprop="url"/>
#         <meta content="864" itemprop="width"/>
#         <meta content="483" itemprop="height"/>
#        </span>
#        <span itemprop="publisher" itemscope="itemscope" itemtype="https://schema.org/Organization">
#         <span content="https://inshorts.com/" itemprop="url">
#         </span>
#         <span content="Inshorts" itemprop="name">
#         </span>
#         <span itemprop="logo" itemscope="" itemtype="https://schema.org/ImageObject">
#          <span content="https://assets.inshorts.com/inshorts/images/v1/variants/jpg/m/2018/11_nov/21_wed/img_1542823931298_497.jpg" itemprop="url">
#          </span>
#          <meta content="400" itemprop="width"/>
#          <meta content="60" itemprop="height"/>
#         </span>
#        </span>
#        <div class="news-card-image" style="background-image: url('https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2020/05_may/25_mon/img_1590416653427_617.jpg?')">
#        </div>
#        <div class="news-card-title news-right-box">
#         <a class="clickable" href="/en/news/lockdown-extensions-wont-help-cases-will-continue-to-rise-anand-mahindra-1590419311635" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'TitleOfNews', 'eventAction': 'clicked', 'eventLabel': 'Lockdown%20extensions%20won't%20help%2C%20cases%20will%20continue%20to%20rise%3A%20Anand%20Mahindra)' });" style="color:#44444d!important">
#          <span itemprop="headline">
#           Lockdown extensions won't help, cases will continue to rise: Anand Mahindra
#          </span>
#         </a>
#         <div class="news-card-author-time news-card-author-time-in-title">
#          <a href="/prev/en/news/lockdown-extensions-wont-help-cases-will-continue-to-rise-anand-mahindra-1590419311635">
#           <span class="short">
#            short
#           </span>
#          </a>
#          by
#          <span class="author">
#           Anushka Dixit
#          </span>
#          /
#          <span class="time" content="2020-05-25T15:08:31.000Z" itemprop="datePublished">
#           08:38 pm
#          </span>
#          on
#          <span clas="date">
#           25 May 2020,Monday
#          </span>
#         </div>
#        </div>
#        <div class="news-card-content news-right-box">
#         <div itemprop="articleBody">
#          Mahindra Group Chairman Anand Mahindra said that "lockdown extensions won't help" adding that the "numbers will continue to rise" regardless. "Lockdown extensions aren't just economically disastrous, but also create another medical crisis," he tweeted. Mahindra added that the government should focus on the expansion of field hospital beds with oxygen lines instead.
#         </div>
#         <div class="news-card-author-time news-card-author-time-in-content">
#          <a href="/prev/en/news/lockdown-extensions-wont-help-cases-will-continue-to-rise-anand-mahindra-1590419311635">
#           <span class="short">
#            short
#           </span>
#          </a>
#          by
#          <span class="author">
#           Anushka Dixit
#          </span>
#          /
#          <span class="time" content="2020-05-25T15:08:31.000Z" itemprop="dateModified">
#           08:38 pm
#          </span>
#          on
#          <span class="date">
#           25 May
#          </span>
#         </div>
#        </div>
#        <div class="news-card-footer news-right-box">
#         <div class="read-more">
#          read more at
#          <a class="source" href="https://twitter.com/anandmahindra/status/1264851749422202880?utm_campaign=fullarticle&amp;utm_medium=referral&amp;utm_source=inshorts " onclick="ga('send', {'hitType': 'event', 'eventCategory': 'ReadMore', 'eventAction': 'clicked', 'eventLabel': 'Twitter' });" target="_blank">
#           Twitter
#          </a>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="">
#       <div class="news-card z-depth-1" itemscope="" itemtype="http://schema.org/NewsArticle">
#        <span content="" itemid="https://inshorts.com/en/news/no-prohibition-in-giving-bank-accounts-to-crypto-traders-rbi-in-rti-reply-1590493313158" itemprop="mainEntityOfPage" itemscope="" itemtype="https://schema.org/WebPage">
#        </span>
#        <span itemprop="author" itemscope="itemscope" itemtype="https://schema.org/Person">
#         <span content="Anushka Dixit" itemprop="name">
#         </span>
#        </span>
#        <span content="No prohibition in giving bank accounts to crypto traders: RBI in RTI reply" itemprop="description">
#        </span>
#        <span itemprop="image" itemscope="" itemtype="https://schema.org/ImageObject">
#         <meta content="https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2020/05_may/26_tue/img_1590490275055_302.jpg?" itemprop="url"/>
#         <meta content="864" itemprop="width"/>
#         <meta content="483" itemprop="height"/>
#        </span>
#        <span itemprop="publisher" itemscope="itemscope" itemtype="https://schema.org/Organization">
#         <span content="https://inshorts.com/" itemprop="url">
#         </span>
#         <span content="Inshorts" itemprop="name">
#         </span>
#         <span itemprop="logo" itemscope="" itemtype="https://schema.org/ImageObject">
#          <span content="https://assets.inshorts.com/inshorts/images/v1/variants/jpg/m/2018/11_nov/21_wed/img_1542823931298_497.jpg" itemprop="url">
#          </span>
#          <meta content="400" itemprop="width"/>
#          <meta content="60" itemprop="height"/>
#         </span>
#        </span>
#        <div class="news-card-image" style="background-image: url('https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2020/05_may/26_tue/img_1590490275055_302.jpg?')">
#        </div>
#        <div class="news-card-title news-right-box">
#         <a class="clickable" href="/en/news/no-prohibition-in-giving-bank-accounts-to-crypto-traders-rbi-in-rti-reply-1590493313158" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'TitleOfNews', 'eventAction': 'clicked', 'eventLabel': 'No%20prohibition%20in%20giving%20bank%20accounts%20to%20crypto%20traders%3A%20RBI%20in%20RTI%20reply)' });" style="color:#44444d!important">
#          <span itemprop="headline">
#           No prohibition in giving bank accounts to crypto traders: RBI in RTI reply
#          </span>
#         </a>
#         <div class="news-card-author-time news-card-author-time-in-title">
#          <a href="/prev/en/news/no-prohibition-in-giving-bank-accounts-to-crypto-traders-rbi-in-rti-reply-1590493313158">
#           <span class="short">
#            short
#           </span>
#          </a>
#          by
#          <span class="author">
#           Anushka Dixit
#          </span>
#          /
#          <span class="time" content="2020-05-26T11:41:53.000Z" itemprop="datePublished">
#           05:11 pm
#          </span>
#          on
#          <span clas="date">
#           26 May 2020,Tuesday
#          </span>
#         </div>
#        </div>
#        <div class="news-card-content news-right-box">
#         <div itemprop="articleBody">
#          The Reserve Bank of India has said that banks are allowed to provide accounts to traders or startups who deal with cryptocurrencies like bitcoin. RBI's clarification came after an RTI was filed by Harish BV, co-founder of cryptocurrency exchange company Unocoin, on April 25. "As on date (May 22, 2020), no such prohibition exists," said RBI's reply last week.
#         </div>
#         <div class="news-card-author-time news-card-author-time-in-content">
#          <a href="/prev/en/news/no-prohibition-in-giving-bank-accounts-to-crypto-traders-rbi-in-rti-reply-1590493313158">
#           <span class="short">
#            short
#           </span>
#          </a>
#          by
#          <span class="author">
#           Anushka Dixit
#          </span>
#          /
#          <span class="time" content="2020-05-26T11:41:53.000Z" itemprop="dateModified">
#           05:11 pm
#          </span>
#          on
#          <span class="date">
#           26 May
#          </span>
#         </div>
#        </div>
#        <div class="news-card-footer news-right-box">
#         <div class="read-more">
#          read more at
# ...
#        </span>
#        <span itemprop="image" itemscope="" itemtype="https://schema.org/ImageObject">
#         <meta content="https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2020/05_may/26_tue/img_1590504994261_682.jpg?" itemprop="url"/>
#         <meta content="864" itemprop="width"/>
#         <meta content="483" itemprop="height"/>
#        </span>
#        <span itemprop="publisher" itemscope="itemscope" itemtype="https://schema.org/Organization">
#         <span content="https://inshorts.com/" itemprop="url">
#         </span>
#         <span content="Inshorts" itemprop="name">
#         </span>
#         <span itemprop="logo" itemscope="" itemtype="https://schema.org/ImageObject">
#          <span content="https://assets.inshorts.com/inshorts/images/v1/variants/jpg/m/2018/11_nov/21_wed/img_1542823931298_497.jpg" itemprop="url">
#          </span>
#          <meta content="400" itemprop="width"/>
#          <meta content="60" itemprop="height"/>
#         </span>
#        </span>
#        <div class="news-card-image" style="background-image: url('https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2020/05_may/26_tue/img_1590504994261_682.jpg?')">
#        </div>
#        <div class="news-card-title news-right-box">
#         <a class="clickable" href="/en/news/vedanta-seeks-shareholders-approval-for-delisting-company-from-nse-bse-1590511190024" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'TitleOfNews', 'eventAction': 'clicked', 'eventLabel': 'Vedanta%20seeks%20shareholders%20approval%20for%20delisting%20company%20from%20NSE%2C%20BSE)' });" style="color:#44444d!important">
#          <span itemprop="headline">
#           Vedanta seeks shareholders approval for delisting company from NSE, BSE
#          </span>
#         </a>
#         <div class="news-card-author-time news-card-author-time-in-title">
#          <a href="/prev/en/news/vedanta-seeks-shareholders-approval-for-delisting-company-from-nse-bse-1590511190024">
#           <span class="short">
#            short
#           </span>
#          </a>
#          by
#          <span class="author">
#           Anushka Dixit
#          </span>
#          /
#          <span class="time" content="2020-05-26T16:39:50.000Z" itemprop="datePublished">
#           10:09 pm
#          </span>
#          on
#          <span clas="date">
#           26 May 2020,Tuesday
#          </span>
#         </div>
#        </div>
#        <div class="news-card-content news-right-box">
#         <div itemprop="articleBody">
#          Billionaire Anil Agarwal-led Vedanta has started the process of getting approval from shareholders for delisting the company from NSE and BSE. Shareholders will be given time till June 24 to cast their votes, after which they cannot be changed. For Vedanta to be delisted successfully, the promoter's stake in the company will have to go up to 90%.
#         </div>
#         <div class="news-card-author-time news-card-author-time-in-content">
#          <a href="/prev/en/news/vedanta-seeks-shareholders-approval-for-delisting-company-from-nse-bse-1590511190024">
#           <span class="short">
#            short
#           </span>
#          </a>
#          by
#          <span class="author">
#           Anushka Dixit
#          </span>
#          /
#          <span class="time" content="2020-05-26T16:39:50.000Z" itemprop="dateModified">
#           10:09 pm
#          </span>
#          on
#          <span class="date">
#           26 May
#          </span>
#         </div>
#        </div>
#        <div class="news-card-footer news-right-box">
#         <div class="read-more">
#          read more at
#          <a class="source" href="https://www.financialexpress.com/industry/vedanta-seeks-shareholders-nod-for-delisting-e-voting-till-june-24/1971241/?utm_campaign=fullarticle&amp;utm_medium=referral&amp;utm_source=inshorts " onclick="ga('send', {'hitType': 'event', 'eventCategory': 'ReadMore', 'eventAction': 'clicked', 'eventLabel': 'The%20Financial%20Express' });" target="_blank">
#           The Financial Express
#          </a>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="">
#       <div class="news-card z-depth-1" itemscope="" itemtype="http://schema.org/NewsArticle">
#        <span content="" itemid="https://inshorts.com/en/news/bharti-telecom-sells-275-stake-in-airtel-raises-₹8433-cr-1590503752555" itemprop="mainEntityOfPage" itemscope="" itemtype="https://schema.org/WebPage">
#        </span>
#        <span itemprop="author" itemscope="itemscope" itemtype="https://schema.org/Person">
#         <span content="Kiran Khatri" itemprop="name">
#         </span>
#        </span>
#        <span content="Bharti Telecom sells 2.75% stake in Airtel, raises ₹8,433 cr" itemprop="description">
#        </span>
#        <span itemprop="image" itemscope="" itemtype="https://schema.org/ImageObject">
#         <meta content="https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2020/05_may/26_tue/img_1590503223342_885.jpg?" itemprop="url"/>
#         <meta content="864" itemprop="width"/>
#         <meta content="483" itemprop="height"/>
#        </span>
#        <span itemprop="publisher" itemscope="itemscope" itemtype="https://schema.org/Organization">
#         <span content="https://inshorts.com/" itemprop="url">
#         </span>
#         <span content="Inshorts" itemprop="name">
#         </span>
#         <span itemprop="logo" itemscope="" itemtype="https://schema.org/ImageObject">
#          <span content="https://assets.inshorts.com/inshorts/images/v1/variants/jpg/m/2018/11_nov/21_wed/img_1542823931298_497.jpg" itemprop="url">
#          </span>
#          <meta content="400" itemprop="width"/>
#          <meta content="60" itemprop="height"/>
#         </span>
#        </span>
#        <div class="news-card-image" style="background-image: url('https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2020/05_may/26_tue/img_1590503223342_885.jpg?')">
#        </div>
#        <div class="news-card-title news-right-box">
#         <a class="clickable" href="/en/news/bharti-telecom-sells-275-stake-in-airtel-raises-₹8433-cr-1590503752555" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'TitleOfNews', 'eventAction': 'clicked', 'eventLabel': 'Bharti%20Telecom%20sells%202.75%25%20stake%20in%20Airtel%2C%20raises%20%E2%82%B98%2C433%20cr)' });" style="color:#44444d!important">
#          <span itemprop="headline">
#           Bharti Telecom sells 2.75% stake in Airtel, raises ₹8,433 cr
#          </span>
#         </a>
#         <div class="news-card-author-time news-card-author-time-in-title">
#          <a href="/prev/en/news/bharti-telecom-sells-275-stake-in-airtel-raises-₹8433-cr-1590503752555">
#           <span class="short">
#            short
#           </span>
#          </a>
#          by
#          <span class="author">
#           Kiran Khatri
#          </span>
#          /
#          <span class="time" content="2020-05-26T14:35:52.000Z" itemprop="datePublished">
#           08:05 pm
#          </span>
#          on
#          <span clas="date">
#           26 May 2020,Tuesday
#          </span>
#         </div>
#        </div>
#        <div class="news-card-content news-right-box">
#         <div itemprop="articleBody">
#          Bharti Telecom has sold 2.75% stake in Airtel to institutional investors in secondary market, raising over ₹8,433 crore. The company said sale proceeds will be utilised to repay debt at Bharti Telecom and will make the promoter holding company "debt free". Bharti Group and Singtel will continue to hold a majority stake in Bharti Airtel at 56.23% after the transaction.
#         </div>
#         <div class="news-card-author-time news-card-author-time-in-content">
#          <a href="/prev/en/news/bharti-telecom-sells-275-stake-in-airtel-raises-₹8433-cr-1590503752555">
#           <span class="short">
#            short
#           </span>
#          </a>
#          by
#          <span class="author">
#           Kiran Khatri
#          </span>
#          /
#          <span class="time" content="2020-05-26T14:35:52.000Z" itemprop="dateModified">
#           08:05 pm
#          </span>
#          on
#          <span class="date">
#           26 May
#          </span>
#         </div>
#        </div>
#        <div class="news-card-footer news-right-box">
#         <div class="read-more">
#          read more at
#          <a class="source" href="https://www.deccanherald.com/business/business-news/bharti-telecom-sells-275-stake-in-airtel-for-rs-8433-cr-to-institutional-investors-842060.html?utm_campaign=fullarticle&amp;utm_medium=referral&amp;utm_source=inshorts " onclick="ga('send', {'hitType': 'event', 'eventCategory': 'ReadMore', 'eventAction': 'clicked', 'eventLabel': 'Deccan%20Herald' });" target="_blank">
#           Deccan Herald
#          </a>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="load-more-wrapper">
#      <div class="clickable unselectable load-more z-depth-1 hoverable" id="load-more-btn" onclick="loadMoreNews()">
#       Load More
#      </div>
#      <div class="clickable unselectable load-more" id="load-more-gif" style="display:none;">
#       <img id="load-more-gif" src="https://assets.inshorts.com/website_assets/images/ajax-loader.gif"/>
#      </div>
#     </div>
#     <div class="my-red app-download-pane hide-on-large-only">
#      <div class="container">
#       <div class="row">
#        <div class="col s12 center" style="color:white;font-weight: 300;font-size:14px;margin-top: 28px;margin-bottom: 18px;">
#         For the best experience use
#         <a href="/mobile" style="color:white;appearance: none;font-weight: 500;" target="_blank">
#          inshorts
#         </a>
#         app on your smartphone
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <!-- BODY END -->
#   <footer class="page-footer teals">
#    <div class="container">
#     <div class="row" style="margin-bottom: 0px; padding-bottom: 5px;">
#      <div class="col offset-l3 l3 m4 s12 right social-admin">
#       <div class="social-share">
#        <a href="https://www.facebook.com/inshortsapp" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkToFaceBookPage', 'eventAction': 'clicked', 'eventLabel': 'RedirectedToFaceBook' });" target="_blank">
#         <img src="https://assets.inshorts.com/website_assets/images/facebook.png"/>
#        </a>
#       </div>
#       <div class="social-share">
#        <a href="https://twitter.com/inshorts" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkToTwitterPage', 'eventAction': 'clicked', 'eventLabel': 'RedirectedToTwitter' });" target="_blank">
#         <img src="https://assets.inshorts.com/website_assets/images/twitter.png"/>
#        </a>
#       </div>
#       <div class="social-share">
#        <a href="https://www.linkedin.com/company/news-in-shorts" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkToLinkedinPage', 'eventAction': 'clicked', 'eventLabel': 'RedirectedToLinkedin' });" target="_blank">
#         <img src="https://assets.inshorts.com/website_assets/images/linkedin.png"/>
#        </a>
#       </div>
#      </div>
#      <div class="col m4 l3 s6 footer-left-pane">
#       <div class="right">
#        <img height="48px" src="https://assets.inshorts.com/website_assets/images/logo_footer.png" width="160px"/>
#       </div>
#       <div class="copy-text">
#        <span>
#         <span style="color:#cfcfcf;font-family: 'Conv_ClanPro-Bold'">
#          inshorts
#         </span>
#         medialabs pvt. ltd.
#        </span>
#        <br/>
#        ©
#        <span style="font-size:12px">
#         COPYRIGHT 2019
#        </span>
#       </div>
#      </div>
#      <div class="col m4 l3 s6 footer-right-pane">
#       <div class="left clickable" id="contactUsBtn" style="margin-top: -5px;">
#        <img height="48px" src="https://assets.inshorts.com/website_assets/images/contact_icon.png" width="132px"/>
#       </div>
#       <div class="terms-text">
#        <a class="tnc" href="/tnc" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkToTermsAndConditionsAndPP', 'eventAction': 'clicked', 'eventLabel': 'RedirectedToTermsAndConditions' });" style="color: #fff;" target="_blank">
#         <span>
#          Terms &amp; conditions
#         </span>
#         <br/>
#         <span>
#          Privacy Policies
#         </span>
#        </a>
#        <br/>
#        <a class="tnc" href="/editorial_policy" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkToSitemap', 'eventAction': 'clicked', 'eventLabel': 'RedirectedToSitemap' });" style="color: #fff;" target="_blank">
#         <span>
#          Editorial Policy
#         </span>
#        </a>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="modal_contact row" id="contactUsModal">
#     <!-- Modal content -->
#     <div class="modal-content col l4 m4 s8 offset-s2 offset-l4 offset-m4">
#      <span class="close">
#       ×
#      </span>
#      <div class="contact">
#       <a href="mailto:careers@inshorts.com?subject=Inshorts%20website%20contact%20form" target="_blank">
#        <button id="myBtn">
#         Contact Hiring Team
#        </button>
#       </a>
#      </div>
#      <div class="contact">
#       <a href="mailto:Admin@inshorts.com?subject=Inshorts%20website%20contact%20form" target="_blank">
#        <button id="myBtn">
#         Contact Admin Team
#        </button>
#       </a>
#      </div>
#      <div class="contact">
#       <a href="mailto:Marketing@inshorts.com?subject=Inshorts%20website%20contact%20form" target="_blank">
#        <button id="myBtn">
#         Contact Marketing Team
#        </button>
#       </a>
#      </div>
#      <div class="contact">
#       <a href="mailto:Editorial@inshorts.com?subject=Inshorts%20website%20contact%20form" target="_blank">
#        <button id="myBtn">
#         Contact Editorial Team
#        </button>
#       </a>
#      </div>
#      <div class="contact">
#       <a href="mailto:Sales@inshorts.com?subject=Inshorts%20website%20contact%20form" target="_blank">
#        <button id="myBtn">
#         Contact Sales Team
#        </button>
#       </a>
#      </div>
#      <div class="contact">
#       <a href="mailto:Contact@inshorts.com?subject=Inshorts%20website%20contact%20form" target="_blank">
#        <button id="myBtn">
#         Contact For Any Other Query
#        </button>
#       </a>
#      </div>
#     </div>
#    </div>
#   </footer>
#   <script>
#    var modal = document.getElementById('contactUsModal');
#
# // Get the button that opens the modal
# var btn = document.getElementById("contactUsBtn");
#
# // Get the <span> element that closes the modal
# var span = document.getElementsByClassName("close")[0];
#
# // When the user clicks on the button, open the modal
# btn.onclick = function() {
#     modal.style.display = "block";
# }
#
# // When the user clicks on <span> (x), close the modal
# span.onclick = function() {
#     modal.style.display = "none";
# }
#
# // When the user clicks anywhere outside of the modal, close it
# window.onclick = function(event) {
#     if (event.target == modal) {
#         modal.style.display = "none";
#     }
# }
#   </script>
#   <!-- Eliminate render-blocking JavaScript and CSS in above-the-fold content -->
#   <script src="https://ajax.googleapis.com/ajax/libs/jquery/1.8/jquery.min.js">
#   </script>
#   <script src="https://cdnjs.cloudflare.com/ajax/libs/materialize/0.97.0/js/materialize.min.js">
#   </script>
#   <script src="/dist/scripts/index.js" type="text/javascript">
#   </script>
#   <script src="/dist/scripts/read.js" type="text/javascript">
#   </script>
#   <script src="/dist/scripts/jquery.scrolldepth.min.js">
#   </script>
#   <script type="text/javascript">
#    var min_news_id = "gnkpc2qv-1";
#     function loadMoreNews(){
#       $("#load-more-btn").hide();
#       $("#load-more-gif").show();
#       $.post("/en/ajax/more_news",{'category':'business','news_offset':min_news_id},function(data){
#           data = JSON.parse(data);
#           min_news_id = data.min_news_id||min_news_id;
#           $(".card-stack").append(data.html);
#       })
#       .fail(function(){alert("Error : unable to load more news");})
#       .always(function(){$("#load-more-btn").show();$("#load-more-gif").hide();});
#     }
#     jQuery.scrollDepth();
#   </script>
#   <!-- Eliminate render-blocking JavaScript and CSS in above-the-fold content -->
#  </body>
# </html>

# %%
titles = []
for card in soup.find_all('span', itemprop="headline"):
    titles.append(card.text)
    
titles
# Out:
# ["India's economic growth seen at 1.2% in Q4 FY20: SBI report",
#  'Glenmark to start clinical trial to test potential COVID-19 drug combination',
#  'Uber India fires 600 employees reducing 25% of its workforce',
#  "TVS Motor cuts employees' salaries by up to 20% for six months",
#  'Firm whose stock surged 1000% in 2020 starts human trials of Covid-19 vaccine',
#  "Lockdown extensions won't help, cases will continue to rise: Anand Mahindra",
#  'No prohibition in giving bank accounts to crypto traders: RBI in RTI reply',
#  'Indian cryptocurrency exchange CoinDCX raises $2.5 million funding',
#  "'Ironic!': Mahindra on China evacuating its citizens from India",
#  'Reliance plans overseas IPO of Facebook-backed Jio in 12-24 months: Report',
#  'India is facing its worst recession in 2020-21: CRISIL',
#  "Tata Steel workers in Netherlands block plant's gates to protest CEO's exit",
#  'India plans to store cheap oil in the US as local storage is full',
#  "Latin America's largest airline files for bankruptcy",
#  "Macau's gambling tycoon Stanley Ho, known as 'King of Gambling', dies at 98",
#  'Prices of N-95 masks down by up to 47% after intervention: Govt',
#  'IDFC First Bank CEO takes 30% pay cut, senior management to take 10% cut',
#  'Foreign investment, tech welcome even as India becomes self-reliant: IT Minister',
#  'US tech executives sold company stock worth over $3.6 bn in May',
#  "Tencent to be Japan's Marvelous' largest shareholder after buying 20% stake",
#  "Facebook renames cryptocurrency Libra's digital wallet 'Calibra' to 'Novi'",
#  'Hyundai resumes operations in 806 sales outlets across India',
#  'Aston Martin CEO Andy Palmer steps down, Mercedes CEO to take over',
#  'Vedanta seeks shareholders approval for delisting company from NSE, BSE',
#  'Bharti Telecom sells 2.75% stake in Airtel, raises ₹8,433 cr']

# %%
bodies = []
for card in soup.find_all('div', itemprop="articleBody"):
    bodies.append(card.text)
    
bodies
# Out:
# ["India's economy is estimated to have grown at 1.2% for the quarter ended March 2020, said the SBI's Ecowrap report. It said the economic activity in the last seven days of March was completely suspended due to lockdown, causing an estimated loss of around ₹1.4 lakh crore. Subsequently, it projected the annual GDP growth for 2019-20 to be around 4.2%.",
#  'Glenmark Pharmaceuticals on Tuesday said it will begin a new clinical trial to test a combination of two antiviral drugs, favipiravir and umifenovir, as a potential COVID-19 treatment. The study will look to enrol 158 hospitalised patients suffering from moderate COVID-19 infections in India. Glenmark is already conducting clinical trials of just favipiravir as a potential COVID-19 treatment.',
#  "Uber is firing 600 employees in India, or 25% of its workforce in the country, amid the coronavirus pandemic. The layoffs, which are a part of Uber's global restructuring plan that eliminated 6,700 jobs, affect teams across customer and driver support, business development, legal, finance, policy and marketing verticals. Affected staff will be paid 10-12 weeks of salary, Uber said.",
#  'TVS Motor Company has said it is cutting the salaries of its employees for six months. Starting May, salaries will be reduced by 5% for junior executives, by 15-20% at senior management level and won\'t be cut at the workmen level. "It was heartening to see employees coming forward and offering to take salary reduction voluntarily," the two-wheeler maker said.',
#  "US biotech company Novavax said it has started Phase 1 clinical trial of its experimental coronavirus vaccine and has enrolled 130 volunteers. Novavax's valuation has surged by over 1,000% this year to about $2.7 billion despite having no products on the market. The trial is being supported by $388 million in funding from the Coalition for Epidemic Preparedness Innovations (CEPI).",
#  'Mahindra Group Chairman Anand Mahindra said that "lockdown extensions won\'t help" adding that the "numbers will continue to rise" regardless. "Lockdown extensions aren\'t just economically disastrous, but also create another medical crisis," he tweeted. Mahindra added that the government should focus on the expansion of field hospital beds with oxygen lines instead. ',
#  'The Reserve Bank of India has said that banks are allowed to provide accounts to traders or startups who deal with cryptocurrencies like bitcoin. RBI\'s clarification came after an RTI was filed by Harish BV, co-founder of cryptocurrency exchange company Unocoin, on April 25. "As on date (May 22, 2020), no such prohibition exists," said RBI\'s reply last week.',
#  "CoinDCX, which claims to be India's largest cryptocurrency exchange, has raised $2.5 million funding led by existing backer Polychain Capital. The investment arm of US-based crypto exchange Coinbase also participated in the round. CoinDCX was founded in 2018 by IIT Bombay alumni Sumit Gupta and Neeraj Khandelwal. In March, the Supreme Court quashed the curbs on cryptocurrency trading in India.",
#  'After China said it will evacuate its citizens from India amid the Covid-19 pandemic, Mahindra Group Chairman Anand Mahindra tweeted, "I have never seen a better occasion to apply the adjective \'Ironic!\'". A notice by the Chinese embassy in India said those willing to return home should register by May 27. The evacuees will have to pay for the tickets.',
#  "Mukesh Ambani-led Reliance Industries is planning an overseas IPO of Jio Platforms in the next 12-24 months but the size hasn't been disclosed, Bloomberg reported. Jio received over $10 billion investment in a month from Facebook, Silver Lake Partners, General Atlantic and KKR. Notably, Ambani had considered taking Jio public in 2017 after investing nearly $31 billion in the carrier. \n",
#  'Ratings agency CRISIL has said that India\'s fourth recession since independence, the first since liberalisation, and the worst to date, is here. The agency predicted that the economy will shrink by 5% in 2020-21 due to coronavirus lockdown and the April-June quarter GDP will contract 25%. "About 10% of GDP in real terms could be permanently lost," CRISIL added.',
#  "Around 100 Tata Steel workers blocked the premises of the Ijmuiden plant in the Netherlands with trucks to protest its CEO Theo Henrar's exit from the company last week. The company's spokesperson said that work had not been affected due to the strike. Henrar left the firm after 33 years over an alleged case of dismissal, Tata's works council said.",
#  'Oil Minister Dharmendra Pradhan said India is looking at storing some low priced US oil in facilities there as the local storage is full. Pradhan added India had already filled its 5.33 million tonnes of strategic storage. Last month, Australia said it would build an emergency oil stockpile, initially by buying crude to store in the US Strategic Petroleum Reserve.',
#  "LATAM Airlines Group, Latin America's largest carrier, on Tuesday said the company and its affiliates in Chile, Peru, Colombia, Ecuador and the US have filed for bankruptcy protection in the US. The Chilean airline said it will continue to fly while it seeks to restructure its debt. This comes two weeks after Latin America's second-largest airline Avianca filed for bankruptcy.",
#  "Stanley Ho, a former kerosene trader who built a casino empire in Macau, has died at age 98, members of his family said on Tuesday. Known as the 'King of Gambling', his Hong Kong-based SJM Holdings Limited helped Macau overtake Las Vegas as the world's gambling capital. SJM now controls 20 casinos on the island of over 25 square kilometres.",
#  'The Ministry of Chemicals and Fertilisers has said that leading manufacturers and importers of N-95 masks have reduced prices by up to 47% after the National Pharmaceutical Pricing Authority (NPPA) intervened. The NPPA issued an advisory to ensure the availability of masks at affordable prices in India. Earlier, N-95 masks were being sold in the market for ₹150-300 per unit. ',
#  "IDFC First Bank's CEO has offered to take a 30% cut in his compensation while the senior management has volunteered to take a 10% pay cut for 2020-21. The bank said it had given full variable pay to 78.2% employees for FY20 despite the COVID-19 crisis. IDFC added it honoured job offers made to new hires before the pandemic hit. \n",
#  "IT Minister Ravi Shankar Prasad has said that foreign direct investment and technology are welcome as India moves to become self-reliant. He clarified that even though PM Modi has been promoting the use of local products, it doesn't mean India will isolate itself from the world. Prasad also called for innovations in artificial intelligence to help tackle the COVID-19 pandemic.",
#  'Executives from US tech companies have collectively sold company shares worth $3.6 billion in May alone, as per SEC filings. Mastercard CEO Ajay Banga sold company shares worth $23.4 million while Netflix CEO Reed Hastings sold over 50,000 shares for $23.9 million. Maximum shares were sold by shareholder of solar energy company Enphase Energy, selling 13,548,476 shares for $819.6 million. ',
#  "Tencent Holdings is buying a 20% stake in Japan's video-game maker Marvelous and will become its largest shareholder. It will spend around $65 million acquiring shares from Marvelous and its largest shareholders, Amuse Capital and its chief executive Hayao Nakayama. Marvelous will sell 8.62 million new shares while Amuse Capital and Hayao will sell 2.83 million and 708,600 shares respectively.",
#  "Facebook has renamed and rebranded 'Calibra', its digital wallet for Libra, to 'Novi' that will help people send and hold Libra digital currencies. Users will be able to use Novi as a stand-alone app, as well as in Messenger and WhatsApp. All Novi customers will be verified using government-issued ID, and fraud protections will be built in throughout the app.",
#  'Hyundai Motor India has resumed operations in 806 dealerships and rural sales outlets while 863 workshops have serviced 1 lakh vehicles in 530 cities in May so far. The company said that it has got nearly 9,000 car bookings and has delivered over 5,600 vehicles across India in 22 days. Hyundai opened its Sriperumbudur plant near Chennai on May 8.\n',
#  "Aston Martin has announced that its CEO Andy Palmer stepped down on Monday and will be replaced by CEO of Mercedes-AMG Tobias Moers on August 1. VP Keith Stanton will serve as the interim CEO until Moers takes over. The leadership change comes after a 98% fall in Aston Martin's share price since it got listed on the stock market. ",
#  "Billionaire Anil Agarwal-led Vedanta has started the process of getting approval from shareholders for delisting the company from NSE and BSE. Shareholders will be given time till June 24 to cast their votes, after which they cannot be changed. For Vedanta to be delisted successfully, the promoter's stake in the company will have to go up to 90%. ",
#  'Bharti Telecom has sold 2.75% stake in Airtel to institutional investors in secondary market, raising over ₹8,433 crore. The company said sale proceeds will be utilised to repay debt at Bharti Telecom and will make the promoter holding company "debt free". Bharti Group and Singtel will continue to hold a majority stake in Bharti Airtel at 56.23% after the transaction.']

# %%
zipped = zip(titles, bodies)

df = pd.DataFrame(columns=['title', 'content', 'category'])

for card in zipped:
    df = df.append({'title': card[0],
                    'content': card[1],
                    'category': 'Business'},
                   ignore_index=True)

# %%
df.head()
# Out:
#                                                title  \
# 0  India's economic growth seen at 1.2% in Q4 FY2...
# 1  Glenmark to start clinical trial to test poten...
# 2  Uber India fires 600 employees reducing 25% of...
# 3  TVS Motor cuts employees' salaries by up to 20...
# 4  Firm whose stock surged 1000% in 2020 starts h...
#
#                                              content  category
# 0  India's economy is estimated to have grown at ...  Business
# 1  Glenmark Pharmaceuticals on Tuesday said it wi...  Business
# 2  Uber is firing 600 employees in India, or 25% ...  Business
# 3  TVS Motor Company has said it is cutting the s...  Business
# 4  US biotech company Novavax said it has started...  Business

# %%
url = 'https://inshorts.com/en/read/business'
regexp = r'https://inshorts.com/en/read/(?P<category>.+)'
category = re.match(regexp, url).groups()[0]
category
# Out:
# 'business'

# %%
# Business Sports Technology Entertainment
def get_inshort_articles(url):
    regexp = r'https://inshorts.com/en/read/(?P<category>.+)'
    category = re.match(regexp, url).groups()[0]
    response = get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # Empty containers
    titles = []
    contents = []
    df = pd.DataFrame(columns=['title', 'content', 'category'])
    
    # List of titles
    for card in soup.find_all('span', itemprop="headline"):
        titles.append(card.text)
    
    # List of contents
    for card in soup.find_all('div', itemprop="articleBody"):
        contents.append(card.text)
    
    # Zip the two lists together and add to df
    zipped = zip(titles, contents)
    for card in zipped:
        df = df.append({'title': card[0],
                        'content': card[1],
                        'category': category},
                      ignore_index=True)
    
    return df

# %%
categories = ['https://inshorts.com/en/read/business',
              'https://inshorts.com/en/read/sports',
              'https://inshorts.com/en/read/technology',
              'https://inshorts.com/en/read/entertainment']
big_df = pd.DataFrame()

for category in categories:
    df = get_inshort_articles(category)
    big_df = big_df.append(df, ignore_index=True)

big_df.head()
# Out:
#                                                title  \
# 0  India's economic growth seen at 1.2% in Q4 FY2...
# 1  Glenmark to start clinical trial to test poten...
# 2  Uber India fires 600 employees reducing 25% of...
# 3  TVS Motor cuts employees' salaries by up to 20...
# 4  Firm whose stock surged 1000% in 2020 starts h...
#
#                                              content  category
# 0  India's economy is estimated to have grown at ...  business
# 1  Glenmark Pharmaceuticals on Tuesday said it wi...  business
# 2  Uber is firing 600 employees in India, or 25% ...  business
# 3  TVS Motor Company has said it is cutting the s...  business
# 4  US biotech company Novavax said it has started...  business

# %%
big_df
# Out:
#                                                 title  \
# 0   India's economic growth seen at 1.2% in Q4 FY2...
# 1   Glenmark to start clinical trial to test poten...
# 2   Uber India fires 600 employees reducing 25% of...
# 3   TVS Motor cuts employees' salaries by up to 20...
# 4   Firm whose stock surged 1000% in 2020 starts h...
# ..                                                ...
# 94  Arjun Bijlani's building sealed after person t...
# 95  It's time we understand what we put our planet...
# 96  Never thought about casting myself for the ser...
# 97  Akshay holds virtual meeting with team of 'Bel...
# 98  The work you're doing is exemplary: Ajay on So...
#
#                                               content       category
# 0   India's economy is estimated to have grown at ...       business
# 1   Glenmark Pharmaceuticals on Tuesday said it wi...       business
# 2   Uber is firing 600 employees in India, or 25% ...       business
# 3   TVS Motor Company has said it is cutting the s...       business
# 4   US biotech company Novavax said it has started...       business
# ..                                                ...            ...
# 94  Actor Arjun Bijlani's building was sealed afte...  entertainment
# 95  Stating that the loss caused by Cyclone Amphan...  entertainment
# 96  On being asked if she ever thought about casti...  entertainment
# 97  Akshay Kumar attended a virtual meeting with t...  entertainment
# 98  Ajay Devgn took to Twitter to appreciate Sonu ...  entertainment
#
# [99 rows x 3 columns]
